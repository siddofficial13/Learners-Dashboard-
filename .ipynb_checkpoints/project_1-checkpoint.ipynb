# %% [markdown]
# # PROJECT  FILE

# %% [markdown]
# # Data Loading

# %% [markdown]
# - Importing the necessary libraries such as pandas,numpy etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import matplotlib.colors as mcolors
import plotly.graph_objects as go  
import plotly.express as px
from scipy.stats import ttest_ind

# %% [markdown]
# - Reading the excel file from the directory and creating the dataframe out of it and print it

# %%
df=pd.read_excel("Coursera Dataset copy.xlsx")

# %%
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#      Completed           Enrollment Time           Completion Time  \
# 0          NaN                       NaN                       NaN
# 1          NaN                       NaN                       NaN
# 2          NaN                       NaN                       NaN
# 3          NaN                       NaN                       NaN
# 4          NaN                       NaN                       NaN
# ...        ...                       ...                       ...
# 6630       Yes  2023-02-15T11:48:06.000Z  2023-03-17T06:11:14.000Z
# 6631        No  2023-04-02T14:10:21.000Z                       NaN
# 6632       NaN                       NaN                       NaN
# 6633       Yes  2023-02-12T12:04:42.000Z  2023-04-02T14:01:56.000Z
# 6634       NaN                       NaN                       NaN
#
#       Learning Hours Spent  Course Grade  \
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4                      NaN           NaN
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                   NaN           NaN
# 6633                  6.34         90.00
# 6634                   NaN           NaN
#
#                                          Skills Learned
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...
# 1     Six Sigma; Training; Culture; Analysis; Leader...
# 2     Process Analysis; Process; Measurement; Genera...
# 3     Trigonometric Integral; Six Sigma; Leadership ...
# 4     Project; Conflict Management; Conflict Resolut...
# ...                                                 ...
# 6630  Data Visualization; Data Analysis; Analysis; P...
# 6631  Supply Chain; Finance; Chaining; Leadership an...
# 6632  Supply Chain; Trigonometric Integral; Lean Six...
# 6633  Data Visualization; Data Analysis; Analysis; P...
# 6634  General Statistics; Statistical Analysis; Prob...
#
# [6635 rows x 13 columns]

# %% [markdown]
# - Columns - 13
# - Rows - 6635

# %%
df.columns
# Out:
# Index(['Name', 'Division', 'Group', 'Department', 'Program Name',
#        'Course Name', 'Duration(in hrs)', 'Completed', 'Enrollment Time',
#        'Completion Time', 'Learning Hours Spent', 'Course Grade',
#        'Skills Learned'],
#       dtype='object')

# %% [markdown]
# - In this given dataset we have the following data columns basically namely:
#
#  0)   Name                            (object)
#  1)   Division                        (object)
#  2)   Group                           (object)
#  3)   Department                     (object)
#  4)   Program Name                    (object)
#  5)   Course Name                     (object)
#  6)   Duration(in hrs)                (float64)
#  7)   Completed                      (object)
#  8)   Enrollment Time                (object)
#  9)   Completion Time                  (object)
#  10)  Learning Hours Spent            (float64)
#  11)  Course Grade                    (float64)
#  12)  Skills Learned                 (object)

# %%
df.describe()
# Out:
#        Duration(in hrs)  Learning Hours Spent  Course Grade
# count       6635.000000           1738.000000   1738.000000
# mean           7.788832              2.968953     41.338423
# std            3.425742              3.892452     41.900973
# min            1.600000              0.000000      0.000000
# 25%            5.800000              0.210000      0.000000
# 50%            6.600000              1.590000     22.500000
# 75%            8.900000              4.377500     87.890000
# max           49.000000             40.940000    100.000000

# %% [markdown]
# - Describe command is basically calculating the metrics of the numerical data
#
# We have three columns for the new numerical dataset namely:-
# 1. Duration(in hrs)
# 2. Learning Hours Spent(in Hrs)
# 3. Course Grade

# %%
df.head()
# Out:
#        Name          Division                Group  \
# 0  Person_1  Operations - TSK  Steel & Mills - TSK
# 1  Person_1  Operations - TSK  Steel & Mills - TSK
# 2  Person_1  Operations - TSK  Steel & Mills - TSK
# 3  Person_1  Operations - TSK  Steel & Mills - TSK
# 4  Person_1  Operations - TSK  Steel & Mills - TSK
#
#                      Department                           Program Name  \
# 0  Steel Melting Shop & LCP TSK  Six Sigma Black Belt Learning Program
# 1  Steel Melting Shop & LCP TSK  Six Sigma Black Belt Learning Program
# 2  Steel Melting Shop & LCP TSK  Six Sigma Black Belt Learning Program
# 3  Steel Melting Shop & LCP TSK  Six Sigma Black Belt Learning Program
# 4  Steel Melting Shop & LCP TSK  Six Sigma Black Belt Learning Program
#
#                                 Course Name  Duration(in hrs) Completed  \
# 0   The Define Phase for the 6 σ Black Belt               5.8       NaN
# 1  The Analyze Phase for the 6 σ Black Belt               7.5       NaN
# 2  The Measure Phase for the 6 σ Black Belt              10.8       NaN
# 3               DFSS for the 6 σ Black Belt               5.0       NaN
# 4    Team Management for the 6 σ Black Belt               2.5       NaN
#
#   Enrollment Time Completion Time  Learning Hours Spent  Course Grade  \
# 0             NaN             NaN                   NaN           NaN
# 1             NaN             NaN                   NaN           NaN
# 2             NaN             NaN                   NaN           NaN
# 3             NaN             NaN                   NaN           NaN
# 4             NaN             NaN                   NaN           NaN
#
#                                       Skills Learned
# 0  Trigonometric Integral; Lean Six Sigma; Six Si...
# 1  Six Sigma; Training; Culture; Analysis; Leader...
# 2  Process Analysis; Process; Measurement; Genera...
# 3  Trigonometric Integral; Six Sigma; Leadership ...
# 4  Project; Conflict Management; Conflict Resolut...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6635 entries, 0 to 6634
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  6635 non-null   object
#  1   Division              6635 non-null   object
#  2   Group                 6635 non-null   object
#  3   Department            6635 non-null   object
#  4   Program Name          6635 non-null   object
#  5   Course Name           6635 non-null   object
#  6   Duration(in hrs)      6635 non-null   float64
#  7   Completed             1738 non-null   object
#  8   Enrollment Time       1738 non-null   object
#  9   Completion Time       675 non-null    object
#  10  Learning Hours Spent  1738 non-null   float64
#  11  Course Grade          1738 non-null   float64
#  12  Skills Learned        6635 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 674.0+ KB

# %% [markdown]
# - Giving the details of the total number of entries in each particular columns which are empty

# %%
df.isnull().sum()
# Out:
# Name                       0
# Division                   0
# Group                      0
# Department                 0
# Program Name               0
# Course Name                0
# Duration(in hrs)           0
# Completed               4897
# Enrollment Time         4897
# Completion Time         5960
# Learning Hours Spent    4897
# Course Grade            4897
# Skills Learned             0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df['Completed']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 6630    Yes
# 6631     No
# 6632    NaN
# 6633    Yes
# 6634    NaN
# Name: Completed, Length: 6635, dtype: object

# %%
df['Completed'].fillna('Not Started Yet',inplace=True)

# %%
df['Completed']
# Out:
# 0       Not Started Yet
# 1       Not Started Yet
# 2       Not Started Yet
# 3       Not Started Yet
# 4       Not Started Yet
#              ...
# 6630                Yes
# 6631                 No
# 6632    Not Started Yet
# 6633                Yes
# 6634    Not Started Yet
# Name: Completed, Length: 6635, dtype: object

# %%
df['Completed'].fillna('Not Started Yet',inplace=True)

# %%
df['Completed']
# Out:
# 0       Not Started Yet
# 1       Not Started Yet
# 2       Not Started Yet
# 3       Not Started Yet
# 4       Not Started Yet
#              ...
# 6630                Yes
# 6631                 No
# 6632    Not Started Yet
# 6633                Yes
# 6634    Not Started Yet
# Name: Completed, Length: 6635, dtype: object

# %% [markdown]
# - In the "Completed" column for the missing values thodse who have not started the course yet have the value "Not Started Yet"

# %%
df.isnull().sum()
# Out:
# Name                       0
# Division                   0
# Group                      0
# Department                 0
# Program Name               0
# Course Name                0
# Duration(in hrs)           0
# Completed                  0
# Enrollment Time         4897
# Completion Time         5960
# Learning Hours Spent    4897
# Course Grade            4897
# Skills Learned             0
# dtype: int64

# %%
type(df['Enrollment Time'])
# Out:
# pandas.core.series.Series

# %%
type(df['Completion Time'])
# Out:
# pandas.core.series.Series

# %%
type(df['Learning Hours Spent'])
# Out:
# pandas.core.series.Series

# %%
type(df['Course Grade'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# - Creating a temporary dataframe df_test so that in case lost the the datframe can anytime be recovered

# %%
type(df['Completion Time'])
# Out:
# pandas.core.series.Series

# %%
df_test=df

# %%
df_test['Completion Time'] = pd.to_datetime(df_test['Completion Time'], errors='coerce', infer_datetime_format=True)
# Out:
# C:\Users\Siddharth\AppData\Local\Temp\ipykernel_5616\3463797058.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_test['Completion Time'] = pd.to_datetime(df_test['Completion Time'], errors='coerce', infer_datetime_format=True)

# %%
df_test['Completion Time']
# Out:
# 0                            NaT
# 1                            NaT
# 2                            NaT
# 3                            NaT
# 4                            NaT
#                   ...
# 6630   2023-03-17 06:11:14+00:00
# 6631                         NaT
# 6632                         NaT
# 6633   2023-04-02 14:01:56+00:00
# 6634                         NaT
# Name: Completion Time, Length: 6635, dtype: datetime64[ns, UTC]

# %%
df_test['Completion Time'] = pd.to_datetime(df_test['Completion Time'], errors='coerce')
# Converting to the desired format
df_test['Formatted Completion Time'] = df_test['Completion Time'].dt.strftime('%d-%m-%y %H:%M:%S')
df_test[['Completion Time', 'Formatted Completion Time']]
# Out:
#                Completion Time Formatted Completion Time
# 0                          NaT                       NaN
# 1                          NaT                       NaN
# 2                          NaT                       NaN
# 3                          NaT                       NaN
# 4                          NaT                       NaN
# ...                        ...                       ...
# 6630 2023-03-17 06:11:14+00:00         17-03-23 06:11:14
# 6631                       NaT                       NaN
# 6632                       NaT                       NaN
# 6633 2023-04-02 14:01:56+00:00         02-04-23 14:01:56
# 6634                       NaT                       NaN
#
# [6635 rows x 2 columns]

# %%
df_test['Formatted Completion Time']
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 6630    17-03-23 06:11:14
# 6631                  NaN
# 6632                  NaN
# 6633    02-04-23 14:01:56
# 6634                  NaN
# Name: Formatted Completion Time, Length: 6635, dtype: object

# %%
type(df_test['Formatted Completion Time'])
# Out:
# pandas.core.series.Series

# %%
df_test['Completion Time']
# Out:
# 0                            NaT
# 1                            NaT
# 2                            NaT
# 3                            NaT
# 4                            NaT
#                   ...
# 6630   2023-03-17 06:11:14+00:00
# 6631                         NaT
# 6632                         NaT
# 6633   2023-04-02 14:01:56+00:00
# 6634                         NaT
# Name: Completion Time, Length: 6635, dtype: datetime64[ns, UTC]

# %%
df['Completion Time'] = pd.to_datetime(df['Completion Time'], errors='coerce')
df['Completion Time'] = df['Completion Time'].dt.strftime('%d-%m-%y %H:%M:%S')

# %%
df['Completion Time']
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 6630    17-03-23 06:11:14
# 6631                  NaN
# 6632                  NaN
# 6633    02-04-23 14:01:56
# 6634                  NaN
# Name: Completion Time, Length: 6635, dtype: object

# %%
df_test['Enrollment Time']
# Out:
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#                   ...
# 6630    2023-02-15T11:48:06.000Z
# 6631    2023-04-02T14:10:21.000Z
# 6632                         NaN
# 6633    2023-02-12T12:04:42.000Z
# 6634                         NaN
# Name: Enrollment Time, Length: 6635, dtype: object

# %%
df['Enrollment Time'] = pd.to_datetime(df['Enrollment Time'], errors='coerce')
df['Enrollment Time'] = df['Enrollment Time'].dt.strftime('%d-%m-%y %H:%M:%S')

# %%
df['Enrollment Time']
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 6630    15-02-23 11:48:06
# 6631    02-04-23 14:10:21
# 6632                  NaN
# 6633    12-02-23 12:04:42
# 6634                  NaN
# Name: Enrollment Time, Length: 6635, dtype: object

# %%
df_test['Completed']
# Out:
# 0       Not Started Yet
# 1       Not Started Yet
# 2       Not Started Yet
# 3       Not Started Yet
# 4       Not Started Yet
#              ...
# 6630                Yes
# 6631                 No
# 6632    Not Started Yet
# 6633                Yes
# 6634    Not Started Yet
# Name: Completed, Length: 6635, dtype: object

# %%
df['Completed']
# Out:
# 0       Not Started Yet
# 1       Not Started Yet
# 2       Not Started Yet
# 3       Not Started Yet
# 4       Not Started Yet
#              ...
# 6630                Yes
# 6631                 No
# 6632    Not Started Yet
# 6633                Yes
# 6634    Not Started Yet
# Name: Completed, Length: 6635, dtype: object

# %%
df_test['Learning Hours Spent']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 6630    7.31
# 6631    2.09
# 6632     NaN
# 6633    6.34
# 6634     NaN
# Name: Learning Hours Spent, Length: 6635, dtype: float64

# %%
df_test['Learning Hours Spent'].isna().sum()
# Out:
# 4897

# %%
df['Learning Hours Spent']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 6630    7.31
# 6631    2.09
# 6632     NaN
# 6633    6.34
# 6634     NaN
# Name: Learning Hours Spent, Length: 6635, dtype: float64

# %%
df['Course Grade']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 6630    90.00
# 6631    33.23
# 6632      NaN
# 6633    90.00
# 6634      NaN
# Name: Course Grade, Length: 6635, dtype: float64

# %%
df.isnull().sum()
# Out:
# Name                            0
# Division                        0
# Group                           0
# Department                      0
# Program Name                    0
# Course Name                     0
# Duration(in hrs)                0
# Completed                       0
# Enrollment Time              4897
# Completion Time              5960
# Learning Hours Spent         4897
# Course Grade                 4897
# Skills Learned                  0
# Formatted Completion Time    5960
# dtype: int64

# %%
dummy_datetime = pd.to_datetime('1900-01-01 00:00:00', format='%Y-%m-%d %H:%M:%S')
df_test['Enrollment Time'].fillna(dummy_datetime, inplace=True)

# %%
df_test['Enrollment Time']
# Out:
# 0       1900-01-01 00:00:00
# 1       1900-01-01 00:00:00
# 2       1900-01-01 00:00:00
# 3       1900-01-01 00:00:00
# 4       1900-01-01 00:00:00
#                ...
# 6630      15-02-23 11:48:06
# 6631      02-04-23 14:10:21
# 6632    1900-01-01 00:00:00
# 6633      12-02-23 12:04:42
# 6634    1900-01-01 00:00:00
# Name: Enrollment Time, Length: 6635, dtype: object

# %% [markdown]
# - Filling all the NaN values with the dummy values of Enrollment time by filling them with the time 1 January 1900 and time will be midnight timming

# %%
df['Completion Time']
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 6630    17-03-23 06:11:14
# 6631                  NaN
# 6632                  NaN
# 6633    02-04-23 14:01:56
# 6634                  NaN
# Name: Completion Time, Length: 6635, dtype: object

# %%
dummy_datetime = pd.to_datetime('1900-01-01 00:00:00', format='%Y-%m-%d %H:%M:%S')
df['Completion Time'].fillna(dummy_datetime, inplace=True)

# %% [markdown]
# - Filling all the NaN values with the dummy values of Complement time by filling them with the time 1 January 1900 and time will be midnight timming

# %%
df.isnull().sum()
# Out:
# Name                            0
# Division                        0
# Group                           0
# Department                      0
# Program Name                    0
# Course Name                     0
# Duration(in hrs)                0
# Completed                       0
# Enrollment Time                 0
# Completion Time                 0
# Learning Hours Spent         4897
# Course Grade                 4897
# Skills Learned                  0
# Formatted Completion Time    5960
# dtype: int64

# %%
df['Completion Time']
# Out:
# 0       1900-01-01 00:00:00
# 1       1900-01-01 00:00:00
# 2       1900-01-01 00:00:00
# 3       1900-01-01 00:00:00
# 4       1900-01-01 00:00:00
#                ...
# 6630      17-03-23 06:11:14
# 6631    1900-01-01 00:00:00
# 6632    1900-01-01 00:00:00
# 6633      02-04-23 14:01:56
# 6634    1900-01-01 00:00:00
# Name: Completion Time, Length: 6635, dtype: object

# %%
df['Learning Hours Spent']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 6630    7.31
# 6631    2.09
# 6632     NaN
# 6633    6.34
# 6634     NaN
# Name: Learning Hours Spent, Length: 6635, dtype: float64

# %%
df_test['Learning Hours Spent'].fillna(0.0, inplace=True)

# %%
df_test['Learning Hours Spent']
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
#         ...
# 6630    7.31
# 6631    2.09
# 6632    0.00
# 6633    6.34
# 6634    0.00
# Name: Learning Hours Spent, Length: 6635, dtype: float64

# %%
df['Learning Hours Spent'].fillna(0.0, inplace=True)

# %% [markdown]
# - Filled all the not availible values with 0.00 in the learning hours column

# %%
df['Learning Hours Spent']
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
#         ...
# 6630    7.31
# 6631    2.09
# 6632    0.00
# 6633    6.34
# 6634    0.00
# Name: Learning Hours Spent, Length: 6635, dtype: float64

# %%
df['Course Grade']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 6630    90.00
# 6631    33.23
# 6632      NaN
# 6633    90.00
# 6634      NaN
# Name: Course Grade, Length: 6635, dtype: float64

# %%
df['Course Grade'].fillna(0.0, inplace=True)

# %% [markdown]
# - Filled all the not availible values with 0.00 in the Course Grade column

# %%
df['Course Grade']
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
#         ...
# 6630    90.00
# 6631    33.23
# 6632     0.00
# 6633    90.00
# 6634     0.00
# Name: Course Grade, Length: 6635, dtype: float64

# %%
df.isnull().sum()
# Out:
# Name                            0
# Division                        0
# Group                           0
# Department                      0
# Program Name                    0
# Course Name                     0
# Duration(in hrs)                0
# Completed                       0
# Enrollment Time                 0
# Completion Time                 0
# Learning Hours Spent            0
# Course Grade                    0
# Skills Learned                  0
# Formatted Completion Time    5960
# dtype: int64

# %%
df['Completion Time']
# Out:
# 0       1900-01-01 00:00:00
# 1       1900-01-01 00:00:00
# 2       1900-01-01 00:00:00
# 3       1900-01-01 00:00:00
# 4       1900-01-01 00:00:00
#                ...
# 6630      17-03-23 06:11:14
# 6631    1900-01-01 00:00:00
# 6632    1900-01-01 00:00:00
# 6633      02-04-23 14:01:56
# 6634    1900-01-01 00:00:00
# Name: Completion Time, Length: 6635, dtype: object

# %%
df['Formatted Completion Time']
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 6630    17-03-23 06:11:14
# 6631                  NaN
# 6632                  NaN
# 6633    02-04-23 14:01:56
# 6634                  NaN
# Name: Formatted Completion Time, Length: 6635, dtype: object

# %%
df.drop(columns=['Formatted Completion Time'], inplace=True)

# %% [markdown]
# - Dropped the unnecessary 'Formatted Completion Time' Column from the dataframe

# %%
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#             Completed      Enrollment Time      Completion Time  \
# 0     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 1     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 2     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 3     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 4     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# ...               ...                  ...                  ...
# 6630              Yes    15-02-23 11:48:06    17-03-23 06:11:14
# 6631               No    02-04-23 14:10:21  1900-01-01 00:00:00
# 6632  Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 6633              Yes    12-02-23 12:04:42    02-04-23 14:01:56
# 6634  Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
#
#       Learning Hours Spent  Course Grade  \
# 0                     0.00          0.00
# 1                     0.00          0.00
# 2                     0.00          0.00
# 3                     0.00          0.00
# 4                     0.00          0.00
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                  0.00          0.00
# 6633                  6.34         90.00
# 6634                  0.00          0.00
#
#                                          Skills Learned
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...
# 1     Six Sigma; Training; Culture; Analysis; Leader...
# 2     Process Analysis; Process; Measurement; Genera...
# 3     Trigonometric Integral; Six Sigma; Leadership ...
# 4     Project; Conflict Management; Conflict Resolut...
# ...                                                 ...
# 6630  Data Visualization; Data Analysis; Analysis; P...
# 6631  Supply Chain; Finance; Chaining; Leadership an...
# 6632  Supply Chain; Trigonometric Integral; Lean Six...
# 6633  Data Visualization; Data Analysis; Analysis; P...
# 6634  General Statistics; Statistical Analysis; Prob...
#
# [6635 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Name                    0
# Division                0
# Group                   0
# Department              0
# Program Name            0
# Course Name             0
# Duration(in hrs)        0
# Completed               0
# Enrollment Time         0
# Completion Time         0
# Learning Hours Spent    0
# Course Grade            0
# Skills Learned          0
# dtype: int64

# %% [markdown]
# - Cleaning the # values present in the dataframe

# %%
hash_counts_per_column = df.apply(lambda x: x.eq('#').sum())
hash_counts_per_column
# Out:
# Name                       0
# Division                   0
# Group                   2080
# Department                 4
# Program Name               0
# Course Name                0
# Duration(in hrs)           0
# Completed                  0
# Enrollment Time            0
# Completion Time            0
# Learning Hours Spent       0
# Course Grade               0
# Skills Learned             0
# dtype: int64

# %%
df_test=df

# %%
df['Group'] = df['Group'].replace('#', 'Not Available')

# %%
hash_counts_per_column = df.apply(lambda x: x.eq('#').sum())
hash_counts_per_column
# Out:
# Name                    0
# Division                0
# Group                   0
# Department              4
# Program Name            0
# Course Name             0
# Duration(in hrs)        0
# Completed               0
# Enrollment Time         0
# Completion Time         0
# Learning Hours Spent    0
# Course Grade            0
# Skills Learned          0
# dtype: int64

# %%
df['Department'] = df['Department'].replace('#', 'Not Available')

# %%
hash_counts_per_column = df.apply(lambda x: x.eq('#').sum())
hash_counts_per_column
# Out:
# Name                    0
# Division                0
# Group                   0
# Department              0
# Program Name            0
# Course Name             0
# Duration(in hrs)        0
# Completed               0
# Enrollment Time         0
# Completion Time         0
# Learning Hours Spent    0
# Course Grade            0
# Skills Learned          0
# dtype: int64

# %%
df_test=df

# %% [markdown]
# # Data Processing And Evaluation

# %%
unique_divisions = df['Division'].unique()
df_unique_divisions = pd.DataFrame({'Unique Divisions': unique_divisions})
df_unique_divisions
# Out:
#                             Unique Divisions
# 0                           Operations - TSK
# 1                                  VP One SC
# 2                                        TSM
# 3                                    M&S(LP)
# 4                                   ED & CFO
# 5                              Raw Materials
# 6                                    M&S(FP)
# 7                                     One IT
# 8                                TQM and E&P
# 9    VP Corp. Finance, Treasury & Risk Mgmt.
# 10                                  VP - GSP
# 11                                       HRM
# 12                               Iron Making
# 13                       Steel Manufacturing
# 14                           Shared Services
# 15                                  CEO & MD
# 16                                       SHS
# 17                                  Tech&NMB
# 18  VP Financial Oprns.& Corporate Reporting
# 19                            Tubes Division
# 20                                       S&S
# 21                        Corporate Services

# %% [markdown]
# - We have 22 different divisions

# %%
unique_persons = df['Name'].unique()
df_unique_persons = pd.DataFrame({'Unique Persons': unique_persons})
df_unique_persons
# Out:
#      Unique Persons
# 0          Person_1
# 1          Person_2
# 2          Person_3
# 3          Person_4
# 4          Person_5
# ...             ...
# 1404    Person_1405
# 1405    Person_1406
# 1406    Person_1407
# 1407    Person_1408
# 1408    Person_1409
#
# [1409 rows x 1 columns]

# %% [markdown]
# - We have 1409 different candidates / persons in the whole dataset

# %%
unique_groups = df['Group'].unique()

df_unique_groups = pd.DataFrame({'Unique Groups': unique_groups})
df_unique_groups
# Out:
#                               Unique Groups
# 0                       Steel & Mills - TSK
# 1             Integrated Planning & Service
# 2                                   Quality
# 3   Chief Commercial Officer (Long Product)
# 4                Portfolio Management & FFI
# ..                                      ...
# 58     Financial Planning & Group Reporting
# 59            Vice President Operations TSM
# 60                            Power Systems
# 61              Security & Brand Protection
# 62                       Finance & Accounts
#
# [63 rows x 1 columns]

# %% [markdown]
# - There are 63 unique groups in the dataframe

# %%
unique_Departments = df['Department'].unique()
df_unique_Departments = pd.DataFrame({'Unique Departments': unique_Departments})
df_unique_Departments
# Out:
#                            Unique Departments
# 0                Steel Melting Shop & LCP TSK
# 1    Master Production Planning & Margin Mgmt
# 2            Scientific Services -Iron Making
# 3                     LP-M&S (TISCON Retail),
# 4      Tax Centre of Excellence- Indirect Tax
# ..                                        ...
# 284                Office of Chief Commercial
# 285                             Not Available
# 286                            CRM Downstream
# 287                 Office of Chief Khondbond
# 288              Mills Mechanical Maintenance
#
# [289 rows x 1 columns]

# %% [markdown]
# - There are 289 different departments

# %%
unique_Programs = df['Program Name'].unique()
df_unique_Programs = pd.DataFrame({'Unique Programs': unique_Programs})
df_unique_Programs
# Out:
#                               Unique Programs
# 0       Six Sigma Black Belt Learning Program
# 1                   School of Analytics-Basic
# 2      Supply Chain Planning Learning Program
# 3              School of Visualization ONE IT
# 4            Teamwork Skills Learning Program
# ..                                        ...
# 129    Google Data Analytics Learning Program
# 130      Communication Roles Learning Program
# 131   Solve Business Problems- AI & ML ONE IT
# 132  Leading Positive Change Learning Program
# 133        Business Strategy Learning Program
#
# [134 rows x 1 columns]

# %% [markdown]
# - There are 134 differnt programs in the dataframe

# %%
unique_Courses = df['Course Name'].unique()
df_unique_Courses = pd.DataFrame({'Unique Courses': unique_Courses})
df_unique_Courses
# Out:
#                                         Unique Courses
# 0              The Define Phase for the 6 σ Black Belt
# 1             The Analyze Phase for the 6 σ Black Belt
# 2             The Measure Phase for the 6 σ Black Belt
# 3                          DFSS for the 6 σ Black Belt
# 4               Team Management for the 6 σ Black Belt
# ..                                                 ...
# 286                         Advanced Business Strategy
# 287                   Foundations of Business Strategy
# 288                   Strategic Planning and Execution
# 289  Business Strategy in Practice (Project-centere...
# 290                           Business Growth Strategy
#
# [291 rows x 1 columns]

# %% [markdown]
# - There are 291 different courses in the dataframe .

# %%
df['Skills Learned']
# Out:
# 0       Trigonometric Integral; Lean Six Sigma; Six Si...
# 1       Six Sigma; Training; Culture; Analysis; Leader...
# 2       Process Analysis; Process; Measurement; Genera...
# 3       Trigonometric Integral; Six Sigma; Leadership ...
# 4       Project; Conflict Management; Conflict Resolut...
#                               ...
# 6630    Data Visualization; Data Analysis; Analysis; P...
# 6631    Supply Chain; Finance; Chaining; Leadership an...
# 6632    Supply Chain; Trigonometric Integral; Lean Six...
# 6633    Data Visualization; Data Analysis; Analysis; P...
# 6634    General Statistics; Statistical Analysis; Prob...
# Name: Skills Learned, Length: 6635, dtype: object

# %%
skills_counts = df_test['Skills Learned'].str.split('; ').explode().value_counts()
df_skills_counts = pd.DataFrame({'Skill': skills_counts.index, 'Count': skills_counts.values})
df_skills_counts
# Out:
#                          Skill  Count
# 0                     Analysis   3160
# 1    Leadership and Management   1607
# 2           Data Visualization   1488
# 3                Data Analysis   1412
# 4           General Statistics   1325
# ..                         ...    ...
# 352           Search Algorithm      1
# 353                     Graphs      1
# 354              Apache Hadoop      1
# 355             Financial Risk      1
# 356     Personal Advertisement      1
#
# [357 rows x 2 columns]

# %% [markdown]
# - There are 357 different skills spanning across all the courses

# %%
df['Learning Hours Spent']
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
#         ...
# 6630    7.31
# 6631    2.09
# 6632    0.00
# 6633    6.34
# 6634    0.00
# Name: Learning Hours Spent, Length: 6635, dtype: float64

# %%
total_learning_hours = df['Learning Hours Spent'].sum()
print("Total Learning Hours Spent:", total_learning_hours)
# Out:
# Total Learning Hours Spent: 5160.04

# %% [markdown]
# # Demographics Of The Dataset

# %% [markdown]
# - Persons - 1409
# - Divisions - 22
# - Group - 63
# - Department- 289
# - Programs - 134
# - Courses - 291
# - Skills- 357
# - Total Learning Hours - 5160

# %%
demographics = {
    'Persons': 1409,
    'Divisions': 22,
    'Group': 63,
    'Department': 289,
    'Programs': 134,
    'Courses': 291,
    'Skills': 357,
    'Total Learning Hours': 5160
}
# Converting demographics dictionary to a DataFrame
demographics_df = pd.DataFrame(list(demographics.items()), columns=['Demographic Components', 'Count'])

# Setting the style of seaborn
sns.set(style="whitegrid")

# Plotting with seaborn
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Demographic Components', y='Count', data=demographics_df, palette='Blues')

# Adding data labels on top of the bars
for p in bar_plot.patches:
    bar_plot.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height()),
                      ha='center', va='bottom', color='black', fontsize=10, fontweight='bold')

# Adding title and labels
plt.title('Demographics of the Dataset', fontsize=16)
plt.xlabel('Demographic Components', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Show the plot
plt.show()

# %%
# Group by 'Division', 'Group', and 'Department' and get the count of learners
distribution_counts_division_group_Department = df.groupby(['Division', 'Group', 'Department']).size().reset_index(name='Learner Count')
distribution_counts_division_group_Department
distribution_counts_division_group_Department_sorted = distribution_counts_division_group_Department.sort_values(by='Learner Count', ascending=False)
distribution_counts_division_group_Department_sorted
# Out:
#                                      Division  \
# 68                                     One IT
# 235                                  Tech&NMB
# 213                                       TSM
# 30                                        HRM
# 202                                       TSM
# ..                                        ...
# 267  VP Financial Oprns.& Corporate Reporting
# 266  VP Financial Oprns.& Corporate Reporting
# 264  VP Financial Oprns.& Corporate Reporting
# 262  VP Financial Oprns.& Corporate Reporting
# 66                                    M&S(LP)
#
#                                         Group                    Department  \
# 68                              Not Available                    Automation
# 235                             Not Available           Scientific Services
# 213                        Khopoli Operations                   Maintenance
# 30                              Not Available        Learning & Development
# 202                      Angul Operation - IM                Blast Furnaces
# ..                                        ...                           ...
# 267                        Office of VP FO&CR  Sust. Reporting & Disclosure
# 266                        Office of VP FO&CR      Financial Controller S&S
# 264      Financial Planning & Group Reporting       Business Analysis Group
# 262  Financial Planning & Corporate Reporting              Capital Planning
# 66                              Not Available      Steel Recycling Business
#
#      Learner Count
# 68             329
# 235            240
# 213            238
# 30             159
# 202            156
# ..             ...
# 267              1
# 266              1
# 264              1
# 262              1
# 66               1
#
# [291 rows x 4 columns]

# %% [markdown]
# - The ONE IT Division and the Automation Department has maximum number of learners enrolled - 329
# - The M&S(LP) Division and the Steel Recycling Business Department has minimum number of learners enrolled - 1

# %% [markdown]
# - The distribution_counts_division_group_Department dataframe will help us track the learners from the three combnination as a whole

# %%
distribution_counts_division_group = df.groupby(['Division', 'Group']).size().reset_index(name='Learner Count')
distribution_counts_division_group
distribution_counts_division_group_sorted = distribution_counts_division_group.sort_values(by='Learner Count', ascending=False)
distribution_counts_division_group_sorted
# Out:
#                                     Division  \
# 21                                    One IT
# 57                                       TSM
# 17                                   M&S(FP)
# 43                               TQM and E&P
# 52                                       TSM
# ..                                       ...
# 74  VP Financial Oprns.& Corporate Reporting
# 50                               TQM and E&P
# 4                        Steel Manufacturing
# 77  VP Financial Oprns.& Corporate Reporting
# 75  VP Financial Oprns.& Corporate Reporting
#
#                                        Group  Learner Count
# 21                             Not Available            861
# 57                        Khopoli Operations            469
# 17                             Not Available            313
# 43                      Design & Engineering            292
# 52                      Angul Operation - IM            288
# ..                                       ...            ...
# 74  Financial Planning & Corporate Reporting              3
# 50               Projects & Construction TSM              3
# 4                              Not Available              3
# 77                        Office of VP FO&CR              2
# 75      Financial Planning & Group Reporting              1
#
# [82 rows x 3 columns]

# %% [markdown]
# - The distribution_counts_division_group will help us to learners with the division and the group
# - The One IT Division has the maximum number of learners enrolled in it with the number being 861
# - The VP Financial Oprns.& Corporate Reporting division  and the Financial Planning & Group Reporting has the minimum number of enrolled learners i.e is 1.

# %%
distribution_counts_division_Department = df.groupby(['Division', 'Department']).size().reset_index(name='Learner Count')
distribution_counts_division_Department
distribution_counts_division_Department_sorted = distribution_counts_division_Department.sort_values(by='Learner Count', ascending=False)
distribution_counts_division_Department_sorted
# Out:
#                                      Division                    Department  \
# 68                                     One IT                    Automation
# 238                                  Tech&NMB           Scientific Services
# 214                                       TSM                   Maintenance
# 29                                        HRM        Learning & Development
# 203                                       TSM                Blast Furnaces
# ..                                        ...                           ...
# 256  VP Financial Oprns.& Corporate Reporting       Business Analysis Group
# 262  VP Financial Oprns.& Corporate Reporting      Financial Controller S&S
# 259  VP Financial Oprns.& Corporate Reporting              Capital Planning
# 267  VP Financial Oprns.& Corporate Reporting  Sust. Reporting & Disclosure
# 65                                    M&S(LP)      Steel Recycling Business
#
#      Learner Count
# 68             329
# 238            240
# 214            238
# 29             159
# 203            156
# ..             ...
# 256              1
# 262              1
# 259              1
# 267              1
# 65               1
#
# [291 rows x 3 columns]

# %% [markdown]
# - This distribution_counts_division_Department dataframe will help us to track the division and department concurrently
# - The maximum number of learners enrolled are in the one it division of the automation department - 329
# - The minimum number of learners enrolled are in the M&S(LP) division of the Steel Recycling Business	 department - 1

# %%
distribution_counts_group_Department = df.groupby(['Group', 'Department']).size().reset_index(name='Learner Count')
distribution_counts_group_Department
distribution_counts_group_Department_sorted = distribution_counts_group_Department.sort_values(by='Learner Count', ascending=False)
distribution_counts_group_Department_sorted
# Out:
#                                         Group                    Department  \
# 158                             Not Available                    Automation
# 193                             Not Available           Scientific Services
# 121                        Khopoli Operations                   Maintenance
# 179                             Not Available        Learning & Development
# 7                        Angul Operation - IM                Blast Furnaces
# ..                                        ...                           ...
# 194                             Not Available      Steel Recycling Business
# 218                        Office of VP FO&CR  Sust. Reporting & Disclosure
# 217                        Office of VP FO&CR      Financial Controller S&S
# 81   Financial Planning & Corporate Reporting              Capital Planning
# 83       Financial Planning & Group Reporting       Business Analysis Group
#
#      Learner Count
# 158            329
# 193            240
# 121            238
# 179            159
# 7              156
# ..             ...
# 194              1
# 218              1
# 217              1
# 81               1
# 83               1
#
# [291 rows x 3 columns]

# %% [markdown]
# - This distribution_counts_division_Department dataframe will help us to track the group and department concurrently

# %% [markdown]
# - Enrolled learners demographics

# %%
# Filtering for the enrolled learners 
enrolled_learners = df

# Group by 'Division' and get the count of enrolled learners
enrolled_by_division = enrolled_learners.groupby('Division').size().reset_index(name='Enrolled Learner Count')
enrolled_by_division
# Out:
#                                     Division  Enrolled Learner Count
# 0                         Corporate Services                       8
# 1                        Steel Manufacturing                     109
# 2                                   CEO & MD                      85
# 3                                   ED & CFO                      28
# 4                                        HRM                     364
# 5                                Iron Making                     333
# 6                                    M&S(FP)                     313
# 7                                    M&S(LP)                     291
# 8                                     One IT                     861
# 9                           Operations - TSK                     389
# 10                             Raw Materials                     568
# 11                                       S&S                      20
# 12                                       SHS                     132
# 13                           Shared Services                     215
# 14                               TQM and E&P                     607
# 15                                       TSM                     999
# 16                                  Tech&NMB                     489
# 17                            Tubes Division                      24
# 18                                  VP - GSP                     232
# 19   VP Corp. Finance, Treasury & Risk Mgmt.                     106
# 20  VP Financial Oprns.& Corporate Reporting                      92
# 21                                 VP One SC                     370

# %%
sns.set(style="whitegrid")

# Plotting the enrolled learners by division
plt.figure(figsize=(12, 8))
bar_plot = sns.barplot(x='Enrolled Learner Count', y='Division', data=enrolled_by_division, palette='viridis')

# Adding data labels on the bars
for p in bar_plot.patches:
    bar_plot.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2),
                      ha='left', va='center', color='black', fontsize=10, fontweight='bold')

# Adding title and labels
plt.title('Number of Enrolled Learners by Division', fontsize=16)
plt.xlabel('Enrolled Learner Count', fontsize=14)
plt.ylabel('Division', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# - The TSM Division is basically having the maximum number of enrolled learners - 999
# - The Corporate Services  Division is basically having the maximum number of enrolled learners - 999

# %%
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#             Completed      Enrollment Time      Completion Time  \
# 0     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 1     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 2     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 3     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 4     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# ...               ...                  ...                  ...
# 6630              Yes    15-02-23 11:48:06    17-03-23 06:11:14
# 6631               No    02-04-23 14:10:21  1900-01-01 00:00:00
# 6632  Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 6633              Yes    12-02-23 12:04:42    02-04-23 14:01:56
# 6634  Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
#
#       Learning Hours Spent  Course Grade  \
# 0                     0.00          0.00
# 1                     0.00          0.00
# 2                     0.00          0.00
# 3                     0.00          0.00
# 4                     0.00          0.00
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                  0.00          0.00
# 6633                  6.34         90.00
# 6634                  0.00          0.00
#
#                                          Skills Learned
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...
# 1     Six Sigma; Training; Culture; Analysis; Leader...
# 2     Process Analysis; Process; Measurement; Genera...
# 3     Trigonometric Integral; Six Sigma; Leadership ...
# 4     Project; Conflict Management; Conflict Resolut...
# ...                                                 ...
# 6630  Data Visualization; Data Analysis; Analysis; P...
# 6631  Supply Chain; Finance; Chaining; Leadership an...
# 6632  Supply Chain; Trigonometric Integral; Lean Six...
# 6633  Data Visualization; Data Analysis; Analysis; P...
# 6634  General Statistics; Statistical Analysis; Prob...
#
# [6635 rows x 13 columns]

# %%
# Group by 'Group' and get the count of enrolled learners
enrolled_by_group = enrolled_learners.groupby('Group').size().reset_index(name='Enrolled Learner Count')
enrolled_by_group
# Out:
#                                       Group  Enrolled Learner Count
# 0                              Agglomerates                      44
# 1                      Angul Operation - IM                     288
# 2                     Angul Operation - SMU                      43
# 3                            Blast Furnaces                     132
# 4   Chief Commercial Officer (Long Product)                     256
# ..                                      ...                     ...
# 58                      Steel & Mills - TSK                      79
# 59                         Tata Growth Shop                      21
# 60                           Transformation                      10
# 61            Vice President Operations TSM                       6
# 62                              West Bokaro                     164
#
# [63 rows x 2 columns]

# %%
# Getting the top 10 groups with the highest enrolled learner count
top_groups = enrolled_by_group.nlargest(10, 'Enrolled Learner Count')

# Set the style of seaborn
sns.set(style="whitegrid")

# Plotting with seaborn
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Enrolled Learner Count', y='Group', data=top_groups, palette='Greens')

# Adding data labels on the right side of the bars
for p in bar_plot.patches:
    bar_plot.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2),
                      ha='left', va='center', color='black', fontsize=10, fontweight='bold')

# Adding title and labels
plt.title('Top 10 Enrolled Groups', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Group', fontsize=14)

# Show the plot
plt.show()

# %%
enrolled_by_department = enrolled_learners.groupby('Department').size().reset_index(name='Enrolled Learner Count')
enrolled_by_department
# Out:
#                 Department  Enrolled Learner Count
# 0                    'MPPI                       6
# 1       A-F Blast Furnaces                      50
# 2           Administration                      20
# 3    Administration Jharia                       6
# 4       Administration OMQ                       6
# ..                     ...                     ...
# 284              Vigilance                      30
# 285          Visualisation                      54
# 286            WCRM & NCRM                      79
# 287             Washery II                       6
# 288            Washery III                      12
#
# [289 rows x 2 columns]

# %%
# Getting the top 10 department with the highest enrolled learner count
top_departments = enrolled_by_department.nlargest(10, 'Enrolled Learner Count')

# Set the style of seaborn
sns.set(style="whitegrid")
# Plotting with seaborn
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Enrolled Learner Count', y='Department', data=top_departments, palette='Blues')
# Adding data labels on the right side of the bars
for p in bar_plot.patches:
    bar_plot.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2),
                      ha='left', va='center', color='black', fontsize=10, fontweight='bold')

# Adding title and labels
plt.title('Top 10 Enrolled Departments', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Department', fontsize=14)
plt.show()

# %%
# Sorting the DataFrame by 'Enrolled Learner Count' in descending order
enrolled_by_group_sorted = enrolled_by_group.sort_values(by='Enrolled Learner Count', ascending=False)

# Getting the group with the maximum count
max_group = enrolled_by_group_sorted.iloc[0]['Group']
max_count = enrolled_by_group_sorted.iloc[0]['Enrolled Learner Count']

# Getting the group with the second maximum count
second_max_group = enrolled_by_group_sorted.iloc[1]['Group']
second_max_count = enrolled_by_group_sorted.iloc[1]['Enrolled Learner Count']

# Getting the group with the minimum count
min_group = enrolled_by_group_sorted.iloc[-1]['Group']
min_count = enrolled_by_group_sorted.iloc[-1]['Enrolled Learner Count']

# Getting the group with the second minimum count
second_min_group = enrolled_by_group_sorted.iloc[-2]['Group']
second_min_count = enrolled_by_group_sorted.iloc[-2]['Enrolled Learner Count']

print("Group with Maximum Count:", max_group, "Count:", max_count)
print("Group with Second Maximum Count:", second_max_group, "Count:", second_max_count)
print("Group with Minimum Count:", min_group, "Count:", min_count)
print("Group with Second Minimum Count:", second_min_group, "Count:", second_min_count)
# Out:
# Group with Maximum Count: Not Available Count: 2080
# Group with Second Maximum Count: Khopoli Operations Count: 469
# Group with Minimum Count: Financial Planning & Group Reporting Count: 1
# Group with Second Minimum Count: Office of VP FO&CR Count: 2

# %%
enrolled_by_group_sorted
# Out:
#                                        Group  Enrolled Learner Count
# 36                             Not Available                    2080
# 29                        Khopoli Operations                     469
# 12                      Design & Engineering                     292
# 1                       Angul Operation - IM                     288
# 4    Chief Commercial Officer (Long Product)                     256
# ..                                       ...                     ...
# 54               Security & Brand Protection                       4
# 20  Financial Planning & Corporate Reporting                       3
# 49               Projects & Construction TSM                       3
# 38                        Office of VP FO&CR                       2
# 21      Financial Planning & Group Reporting                       1
#
# [63 rows x 2 columns]

# %%
# Sorting the DataFrame by 'Enrolled Learner Count' in descending order
enrolled_by_division_sorted = enrolled_by_division.sort_values(by='Enrolled Learner Count', ascending=False)

# Getting the group with the maximum count
max_division = enrolled_by_division_sorted.iloc[0]['Division']
max_count = enrolled_by_division_sorted.iloc[0]['Enrolled Learner Count']

# Getting the group with the second maximum count
second_max_division = enrolled_by_division_sorted.iloc[1]['Division']
second_max_count = enrolled_by_division_sorted.iloc[1]['Enrolled Learner Count']

# Getting the group with the minimum count
min_division = enrolled_by_division_sorted.iloc[-1]['Division']
min_count = enrolled_by_division_sorted.iloc[-1]['Enrolled Learner Count']

# Getting the group with the second minimum count
second_min_division = enrolled_by_division_sorted.iloc[-2]['Division']
second_min_count = enrolled_by_division_sorted.iloc[-2]['Enrolled Learner Count']

print("Division with Maximum Count:", max_division, "Count:", max_count)
print("Division with Second Maximum Count:", second_max_division, "Count:", second_max_count)
print("Division with Minimum Count:", min_division, "Count:", min_count)
print("Division with Second Minimum Count:", second_min_division, "Count:", second_min_count)
# Out:
# Division with Maximum Count: TSM Count: 999
# Division with Second Maximum Count: One IT Count: 861
# Division with Minimum Count:  Corporate Services Count: 8
# Division with Second Minimum Count: S&S Count: 20

# %%
enrolled_by_division_sorted
# Out:
#                                     Division  Enrolled Learner Count
# 15                                       TSM                     999
# 8                                     One IT                     861
# 14                               TQM and E&P                     607
# 10                             Raw Materials                     568
# 16                                  Tech&NMB                     489
# 9                           Operations - TSK                     389
# 21                                 VP One SC                     370
# 4                                        HRM                     364
# 5                                Iron Making                     333
# 6                                    M&S(FP)                     313
# 7                                    M&S(LP)                     291
# 18                                  VP - GSP                     232
# 13                           Shared Services                     215
# 12                                       SHS                     132
# 1                        Steel Manufacturing                     109
# 19   VP Corp. Finance, Treasury & Risk Mgmt.                     106
# 20  VP Financial Oprns.& Corporate Reporting                      92
# 2                                   CEO & MD                      85
# 3                                   ED & CFO                      28
# 17                            Tubes Division                      24
# 11                                       S&S                      20
# 0                         Corporate Services                       8

# %%
program_counts = df.groupby('Program Name').size().reset_index(name='Learner Count')
# Sort the DataFrame by 'Learner Count' in descending order
most_popular_programs = program_counts.sort_values(by='Learner Count', ascending=False)
most_popular_programs
# Out:
#                                  Program Name  Learner Count
# 104                 School of Analytics-Basic           2026
# 105                      School of Blockchain            588
# 96      Project Mgmt Learning Program-Generic            408
# 13    Business Communication Learning Program            384
# 111     Six Sigma Black Belt Learning Program            360
# ..                                        ...            ...
# 75             MATLAB Learning Program ONE IT              1
# 71   Leading Positive Change Learning Program              1
# 48            Finance Learning Program ONE IT              1
# 66         Innovation and emerging technology              1
# 76            ML & AI on GCP Learning Program              1
#
# [134 rows x 2 columns]

# %% [markdown]
# - The most popular programs which can be clearly seen as are "School Of Analytics-Basic" , "School Of Blockchain", "Project Mgmt Learning Program-Generic" followed by "Business Communication Learning Program"

# %%
# Calculating the completion rates for each course
course_completion_rates = df.groupby('Course Name')['Completed'].apply(lambda x: x.eq('Yes').sum() / x.notna().sum()).reset_index(name='Completion Rate')
course_completion_rates
# Out:
#                                            Course Name  Completion Rate
# 0               AI Capstone Project with Deep Learning         0.034483
# 1                                      AI For Everyone         0.000000
# 2                        AI Workflow: AI in Production         0.000000
# 3    AI Workflow: Business Priorities and Data Inge...         0.000000
# 4    AI Workflow: Data Analysis and Hypothesis Testing         0.000000
# ..                                                 ...              ...
# 286                      Transacting on the Blockchain         0.013605
# 287  User Experience & Interaction Design for AR/VR...         0.000000
# 288                      Visual Analytics with Tableau         0.014286
# 289                              What is Data Science?         0.083333
# 290  Work Smarter Not Harder: Time Management for P...         0.200000
#
# [291 rows x 2 columns]

# %%
enrolled_learners = df[df['Enrollment Time'] != 'Not Started Yet']

# Grouping by the 'Program Name' and 'Course Name'
program_completion_summary = enrolled_learners.groupby(['Program Name', 'Course Name'])['Completed'].agg(
    TotalLearners='count',
    CompletedLearners=lambda x: x.eq('Yes').sum(),
    CompletionRate=lambda x: x.eq('Yes').sum() / x.notna().sum(),
    CompletionRatePercentage=lambda x: (x.eq('Yes').sum() / x.notna().sum()) * 100
).reset_index()
program_completion_summary
# Out:
#                                 Program Name  \
# 0     AI Engineering Learning Program ONE IT
# 1     AI Engineering Learning Program ONE IT
# 2     AI Engineering Learning Program ONE IT
# 3     AI Engineering Learning Program ONE IT
# 4     AI Engineering Learning Program ONE IT
# ..                                       ...
# 321           Visualization Learning Program
# 322           Visualization Learning Program
# 323  Web Development Learning Program ONE IT
# 324  Web Development Learning Program ONE IT
# 325  Web Development Learning Program ONE IT
#
#                                            Course Name  TotalLearners  \
# 0               AI Capstone Project with Deep Learning             29
# 1        Building Deep Learning Models with TensorFlow             29
# 2                    Deep Neural Networks with PyTorch             29
# 3    Introduction to Deep Learning & Neural Network...             29
# 4                         Machine Learning with Python             29
# ..                                                 ...            ...
# 321                          Python Data Visualization              1
# 322                      Visual Analytics with Tableau              1
# 323                                     Advanced React              5
# 324                                       React Basics              5
# 325  Responsive Website Basics: Code with HTML CSS ...              5
#
#      CompletedLearners  CompletionRate  CompletionRatePercentage
# 0                    1        0.034483                  3.448276
# 1                    2        0.068966                  6.896552
# 2                    2        0.068966                  6.896552
# 3                    7        0.241379                 24.137931
# 4                   12        0.413793                 41.379310
# ..                 ...             ...                       ...
# 321                  0        0.000000                  0.000000
# 322                  0        0.000000                  0.000000
# 323                  0        0.000000                  0.000000
# 324                  0        0.000000                  0.000000
# 325                  0        0.000000                  0.000000
#
# [326 rows x 6 columns]

# %%
program_completion_summary_sorted = program_completion_summary.sort_values(by='CompletionRatePercentage', ascending=False)
program_completion_summary_sorted
# Out:
#                                 Program Name  \
# 55   Computer Vision with Tensor Flow ONE IT
# 276       Software Defined Networking ONE IT
# 254  Security Engineering  Learn Prog ONE IT
# 253  Security Engineering  Learn Prog ONE IT
# 246            Scrum Master Learning Program
# ..                                       ...
# 186      Marketing Strategy Learning Program
# 187      Marketing Strategy Learning Program
# 188      Marketing Strategy Learning Program
# 189      Marketing Strategy Learning Program
# 325  Web Development Learning Program ONE IT
#
#                                            Course Name  TotalLearners  \
# 55            Advanced Computer Vision with TensorFlow              1
# 276  Intel® Network Academy - Network Transformatio...              1
# 254  Introduction to Cybersecurity Tools & Cyber At...              1
# 253  Cybersecurity Compliance Framework & System Ad...              1
# 246              Introduction to Scrum Master Training              5
# ..                                                 ...            ...
# 186              Market Research and Consumer Behavior              9
# 187                         Marketing Mix Fundamentals              9
# 188                Marketing Strategy Capstone Project              9
# 189  Positioning: What you need for a successful Ma...              9
# 325  Responsive Website Basics: Code with HTML CSS ...              5
#
#      CompletedLearners  CompletionRate  CompletionRatePercentage
# 55                   1             1.0                     100.0
# 276                  1             1.0                     100.0
# 254                  1             1.0                     100.0
# 253                  1             1.0                     100.0
# 246                  5             1.0                     100.0
# ..                 ...             ...                       ...
# 186                  0             0.0                       0.0
# 187                  0             0.0                       0.0
# 188                  0             0.0                       0.0
# 189                  0             0.0                       0.0
# 325                  0             0.0                       0.0
#
# [326 rows x 6 columns]

# %%
unique_completion_rates = program_completion_summary_sorted['CompletionRatePercentage'].nunique()
print(f'Number of unique completion rate percentages: {unique_completion_rates}')
# Out:
# Number of unique completion rate percentages: 58

# %%
completion_rate_counts = program_completion_summary_sorted['CompletionRatePercentage'].round(1).value_counts().reset_index()
completion_rate_counts.columns = ['CompletionRatePercentage', 'Frequency']

# Convert to dictionary
completion_rate_dict = dict(zip(completion_rate_counts['CompletionRatePercentage'], completion_rate_counts['Frequency']))
completion_rate_dict
# Out:
# {0.0: 206,
#  100.0: 20,
#  33.3: 10,
#  50.0: 7,
#  60.0: 5,
#  16.7: 5,
#  14.3: 4,
#  1.4: 3,
#  2.2: 3,
#  4.4: 3,
#  6.9: 3,
#  5.4: 2,
#  5.7: 2,
#  6.2: 2,
#  6.7: 2,
#  6.8: 2,
#  8.3: 2,
#  10.0: 2,
#  12.5: 2,
#  12.7: 2,
#  25.0: 2,
#  24.1: 2,
#  2.1: 1,
#  40.0: 1,
#  2.7: 1,
#  3.1: 1,
#  3.4: 1,
#  4.2: 1,
#  24.5: 1,
#  30.8: 1,
#  4.5: 1,
#  4.9: 1,
#  5.0: 1,
#  26.7: 1,
#  5.6: 1,
#  25.7: 1,
#  41.4: 1,
#  4.3: 1,
#  16.9: 1,
#  18.8: 1,
#  7.5: 1,
#  16.4: 1,
#  15.6: 1,
#  15.4: 1,
#  18.9: 1,
#  13.7: 1,
#  13.5: 1,
#  13.3: 1,
#  80.0: 1,
#  20.0: 1,
#  11.1: 1,
#  10.5: 1,
#  22.2: 1,
#  8.5: 1,
#  23.6: 1,
#  8.1: 1,
#  24.4: 1}

# %%
rounded_completion_rate_counts = completion_rate_counts.copy()
rounded_completion_rate_counts['CompletionRatePercentage'] = rounded_completion_rate_counts['CompletionRatePercentage'].round().astype(int)
rounded_completion_rate_dict = dict(zip(rounded_completion_rate_counts['CompletionRatePercentage'], rounded_completion_rate_counts['Frequency']))

# Display the updated dictionary
rounded_completion_rate_dict
# Out:
# {0: 206,
#  100: 20,
#  33: 10,
#  50: 7,
#  60: 5,
#  17: 1,
#  14: 1,
#  1: 3,
#  2: 1,
#  4: 1,
#  7: 2,
#  5: 1,
#  6: 1,
#  8: 1,
#  10: 1,
#  12: 2,
#  13: 1,
#  25: 2,
#  24: 1,
#  40: 1,
#  3: 1,
#  31: 1,
#  27: 1,
#  26: 1,
#  41: 1,
#  19: 1,
#  16: 1,
#  15: 1,
#  80: 1,
#  20: 1,
#  11: 1,
#  22: 1}

# %%
rounded_completion_rate_df = pd.DataFrame(list(rounded_completion_rate_dict.items()), columns=['CompletionRatePercentage', 'Frequency'])

ranges = [
    {'label': '0%', 'start': -0.1, 'end': 0},
    {'label': '1-30%', 'start': 0.1, 'end': 30},
    {'label': '31-65%', 'start': 30.1, 'end': 65},
    {'label': '66-99%', 'start': 65.1, 'end': 99.9},
    {'label': '100%', 'start': 100, 'end': 100}
]

# Categorize completion rates
rounded_completion_rate_df['Category'] = pd.cut(
    rounded_completion_rate_df['CompletionRatePercentage'],
    bins=[range['start'] for range in ranges] + [float('inf')],
    labels=[range['label'] for range in ranges],
    right=False
)

# Group by category and sum the frequencies
category_counts = rounded_completion_rate_df.groupby('Category')['Frequency'].sum().reset_index()

# Set a custom color palette
custom_palette = ["#264653", "#2a9d8f", "#e9c46a", "#f4a261", "#e76f51"]

# Set a larger figure size
plt.figure(figsize=(12, 10))

# Plotting the pie chart
plt.pie(category_counts['Frequency'], labels=category_counts['Category'],
        autopct='%1.1f%%', startangle=160, wedgeprops=dict(width=1.0), textprops=dict(color="w"))

# Adding a legend
plt.legend(title="Completion Rate", loc="upper left", bbox_to_anchor=(1, 0.8))

# Adding a title
plt.title("Distribution of Completion Rates", fontsize=16)

# Show the plot
plt.show()

# %%
enrolled_learners = df[df['Enrollment Time'] != 'Not Started Yet']

# Group by 'Course Name' and calculate completion rates
course_completion_rates = enrolled_learners.groupby('Course Name')['Completed'].agg(
    TotalLearners='count',
    CompletedLearners=lambda x: x.eq('Yes').sum(),
    CompletionRate=lambda x: x.eq('Yes').sum() / x.notna().sum()
).reset_index()

# Set your threshold for significantly higher or lower completion rates (adjust as needed)
threshold_higher = 0.8
threshold_lower = 0.04

# Identify courses with significantly higher completion rates
higher_completion_courses = course_completion_rates[course_completion_rates['CompletionRate'] > threshold_higher]

# Identify courses with significantly lower completion rates
lower_completion_courses = course_completion_rates[course_completion_rates['CompletionRate'] < threshold_lower]

# %%
higher_completion_courses
# Out:
#                                            Course Name  TotalLearners  \
# 13            Advanced Computer Vision with TensorFlow              1
# 21                Artificial Intelligence in Marketing              1
# 34                           Build personal resilience              1
# 39            Business English: Planning & Negotiating              1
# 46      Calculus for Machine Learning and Data Science              1
# 49                  Cloud Computing Basics (Cloud 101)              2
# 53      Computer Vision with Embedded Machine Learning              1
# 102  Engineering Project Management: Initiating and...              1
# 103  Engineering Project Management: Risk, Quality,...              1
# 104  Engineering Project Management: Scope, Time an...              1
# 105             Enterprise and Infrastructure Security              1
# 122                               From Idea to Startup              1
# 154  Intel® Network Academy - Network Transformatio...              1
# 155  Intel® Network Academy - Network Transformatio...              1
# 169              Introduction to Scrum Master Training              6
# 176             Leading transformations: Manage change              1
# 178  Linear Algebra for Machine Learning and Data S...              1
# 251  Smart Analytics Machine Learning and AI on Goo...              1
#
#      CompletedLearners  CompletionRate
# 13                   1        1.000000
# 21                   1        1.000000
# 34                   1        1.000000
# 39                   1        1.000000
# 46                   1        1.000000
# 49                   2        1.000000
# 53                   1        1.000000
# 102                  1        1.000000
# 103                  1        1.000000
# 104                  1        1.000000
# 105                  1        1.000000
# 122                  1        1.000000
# 154                  1        1.000000
# 155                  1        1.000000
# 169                  5        0.833333
# 176                  1        1.000000
# 178                  1        1.000000
# 251                  1        1.000000

# %%
higher_completion_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 13 to 251
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Course Name        18 non-null     object
#  1   TotalLearners      18 non-null     int64
#  2   CompletedLearners  18 non-null     int64
#  3   CompletionRate     18 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 720.0+ bytes

# %%
lower_completion_courses
# Out:
#                                            Course Name  TotalLearners  \
# 0               AI Capstone Project with Deep Learning             29
# 1                                      AI For Everyone              3
# 2                        AI Workflow: AI in Production              2
# 3    AI Workflow: Business Priorities and Data Inge...              2
# 4    AI Workflow: Data Analysis and Hypothesis Testing              2
# ..                                                 ...            ...
# 284                             Tools for Data Science              3
# 285                       Training and Learning Online              1
# 286                      Transacting on the Blockchain            147
# 287  User Experience & Interaction Design for AR/VR...              1
# 288                      Visual Analytics with Tableau             70
#
#      CompletedLearners  CompletionRate
# 0                    1        0.034483
# 1                    0        0.000000
# 2                    0        0.000000
# 3                    0        0.000000
# 4                    0        0.000000
# ..                 ...             ...
# 284                  0        0.000000
# 285                  0        0.000000
# 286                  2        0.013605
# 287                  0        0.000000
# 288                  1        0.014286
#
# [185 rows x 4 columns]

# %%
lower_completion_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 0 to 288
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Course Name        185 non-null    object
#  1   TotalLearners      185 non-null    int64
#  2   CompletedLearners  185 non-null    int64
#  3   CompletionRate     185 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# - This higher_completion_courses and the lower_completion_courses will show the list of records having completion rate higher than 80% and lower completion will show records having the records having completion rates lower than 4%

# %%
courses_with_zero_completion_rate = course_completion_rates[course_completion_rates['CompletionRate'] == 0.00]
courses_with_zero_completion_rate
# Out:
#                                            Course Name  TotalLearners  \
# 1                                      AI For Everyone              3
# 2                        AI Workflow: AI in Production              2
# 3    AI Workflow: Business Priorities and Data Inge...              2
# 4    AI Workflow: Data Analysis and Hypothesis Testing              2
# 5             AI Workflow: Enterprise Model Deployment              2
# ..                                                 ...            ...
# 280                                 The Marketing Plan              9
# 283           Think Outside the Inbox: Email Marketing             14
# 284                             Tools for Data Science              3
# 285                       Training and Learning Online              1
# 287  User Experience & Interaction Design for AR/VR...              1
#
#      CompletedLearners  CompletionRate
# 1                    0             0.0
# 2                    0             0.0
# 3                    0             0.0
# 4                    0             0.0
# 5                    0             0.0
# ..                 ...             ...
# 280                  0             0.0
# 283                  0             0.0
# 284                  0             0.0
# 285                  0             0.0
# 287                  0             0.0
#
# [175 rows x 4 columns]

# %%
completed_learners = df[(df['Completed'] == 'Yes') & df['Learning Hours Spent'].notna()]
average_learning_hours = completed_learners['Learning Hours Spent'].mean()
average_learning_hours
# Out:
# 5.479644444444444

# %%
completed_learners = df[(df['Completed'] == 'Yes') & df['Learning Hours Spent'].notna()]
average_learning_hours_per_course = completed_learners.groupby('Course Name')['Learning Hours Spent'].mean().reset_index(name='Average Learning Hours')
average_learning_hours_per_course
# Out:
#                                            Course Name  Average Learning Hours
# 0               AI Capstone Project with Deep Learning                 4.45000
# 1             Advanced Computer Vision with TensorFlow                 3.17000
# 2                        Applied Data Science Capstone                 0.98500
# 3                 Artificial Intelligence in Marketing                 0.81000
# 4    Basic Data Descriptors Statistical Distributio...                 5.92066
# ..                                                 ...                     ...
# 111             The Nuts and Bolts of Public Relations                 5.21000
# 112                      Transacting on the Blockchain                 4.21500
# 113                      Visual Analytics with Tableau                 0.82000
# 114                              What is Data Science?                 1.67000
# 115  Work Smarter Not Harder: Time Management for P...                 4.19000
#
# [116 rows x 2 columns]

# %% [markdown]
# - This is only for those learners data who have completed the course atleast once

# %%
completed_learners_all = df[df['Learning Hours Spent'].notna()]
average_learning_hours_all = completed_learners_all['Learning Hours Spent'].mean()
average_learning_hours_all
# Out:
# 0.7777000753579503

# %%
average_learning_hours_per_course_all = completed_learners_all.groupby('Course Name')['Learning Hours Spent'].mean().reset_index(name='Average Learning Hours')
average_learning_hours_per_course_all
# Out:
#                                            Course Name  Average Learning Hours
# 0               AI Capstone Project with Deep Learning                 0.16069
# 1                                      AI For Everyone                 0.00000
# 2                        AI Workflow: AI in Production                 0.00000
# 3    AI Workflow: Business Priorities and Data Inge...                 0.00000
# 4    AI Workflow: Data Analysis and Hypothesis Testing                 0.00000
# ..                                                 ...                     ...
# 286                      Transacting on the Blockchain                 0.16551
# 287  User Experience & Interaction Design for AR/VR...                 0.00000
# 288                      Visual Analytics with Tableau                 0.04400
# 289                              What is Data Science?                 0.23500
# 290  Work Smarter Not Harder: Time Management for P...                 0.83800
#
# [291 rows x 2 columns]

# %% [markdown]
# - This is the average learning hours for all the courses

# %%
learners_atleast_started_the_course = df[(df['Completed'] != 'Not Started Yet')]
learners_atleast_started_the_course['Completed'] = learners_atleast_started_the_course['Completed'].map({'Yes': 1, 'No': 0})

# Plot a scatter plot with logistic regression line
sns.regplot(x='Learning Hours Spent', y='Completed', data=learners_atleast_started_the_course, logistic=True, scatter_kws={'alpha': 0.1})

# Show the plot
plt.title('Correlation between Learning Hours and Course Completion')
plt.xlabel('Learning Hours Spent')
plt.ylabel('Course Completion (1: Completed, 0: Not Completed)')
plt.show()
# Out:
# C:\Users\Siddharth\AppData\Local\Temp\ipykernel_5616\3795878626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learners_atleast_started_the_course['Completed'] = learners_atleast_started_the_course['Completed'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# - Scatter Plot:
#
# - Each point on the scatter plot represents a data point with the learning hours spent on the x-axis and the completion status on the y-axis.
# - Points with a value of 1 on the y-axis indicate completed courses, and points with a value of 0 indicate not completed courses.
#
# - Logistic Regression Line:
#
# - The logistic regression line is a curve that represents the best fit to the relationship between learning hours and the probability of course completion.
# - It shows how the probability of course completion changes as the learning hours increase.
#
# - Interpretation:
#
# - The logistic regression line slopes upward, it suggests a positive correlation, indicating that higher learning hours are associated with a higher probability of course completion.
#
# - Alpha Parameter:
#
# - The scatter_kws={'alpha': 0.1} parameter is used to control the transparency of the scatter plot points. A lower alpha value (closer to 0) makes the points more transparent, helping to visualize areas with higher point density.

# %%
correlation = learners_atleast_started_the_course['Learning Hours Spent'].corr(learners_atleast_started_the_course['Course Grade'])
correlation
# Out:
# 0.5776350953280784

# %%
course_wise_correlation = learners_atleast_started_the_course.groupby('Course Name').apply(lambda group: group['Learning Hours Spent'].corr(group['Course Grade'])).reset_index(name='Correlation')

course_wise_correlation
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
#                                            Course Name  Correlation
# 0               AI Capstone Project with Deep Learning     1.000000
# 1       Accounting: Principles of Financial Accounting          NaN
# 2             Advanced Computer Vision with TensorFlow          NaN
# 3                                       Advanced React          NaN
# 4                                    Algorithms Part I          NaN
# ..                                                 ...          ...
# 174                             Tools for Data Science          NaN
# 175                      Transacting on the Blockchain     0.729776
# 176                      Visual Analytics with Tableau    -1.000000
# 177                              What is Data Science?     1.000000
# 178  Work Smarter Not Harder: Time Management for P...          NaN
#
# [179 rows x 2 columns]

# %%
learners_atleast_started_the_course['Completed'] = learners_atleast_started_the_course['Completed'].map({'Yes': 1, 'No': 0})

course_wise_correlation = learners_atleast_started_the_course.groupby('Course Name').apply(lambda group: group['Learning Hours Spent'].corr(group['Course Grade'])).reset_index(name='Correlation')

# Define the bins for categorization
bins = [-np.inf, -1, 0, 1, np.inf]

# Categorize the correlation values into bins and calculate value counts
correlation_bins = pd.cut(course_wise_correlation['Correlation'], bins=bins)
correlation_counts = correlation_bins.value_counts(dropna=False)

# Plotting a pie chart using Seaborn
custom_palette = ["#264653", "#2a9d8f", "#e9c46a", "#f4a261"]
plt.figure(figsize=(10, 10))
sns.set_palette(custom_palette)  # Set a color palette

# Plot a pie chart using correlation_counts
plt.pie(correlation_counts, labels=[''] * len(correlation_counts), autopct='', startangle=90)

# Create a legend
legend_labels = [f'{label} ({percentage:.1f}%)' for label, percentage in zip(correlation_counts.index, correlation_counts / correlation_counts.sum() * 100)]
plt.legend(title='Correlation Range', labels=legend_labels, loc='upper left')

# Show the plot
plt.title('Distribution of Correlation Values')
plt.show()
# Out:
# C:\Users\Siddharth\AppData\Local\Temp\ipykernel_5616\1552642588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learners_atleast_started_the_course['Completed'] = learners_atleast_started_the_course['Completed'].map({'Yes': 1, 'No': 0})
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)

# %% [markdown]
# - 51 percent of the enrolled learners have positive correlation and the 45 percent of the users have NaN correlation meaning they havent started the course also yet and the remaining 4 percent learners have neagtive correlation between the course grade anf the learning hours

# %%
df['Completed']
# Out:
# 0       Not Started Yet
# 1       Not Started Yet
# 2       Not Started Yet
# 3       Not Started Yet
# 4       Not Started Yet
#              ...
# 6630                Yes
# 6631                 No
# 6632    Not Started Yet
# 6633                Yes
# 6634    Not Started Yet
# Name: Completed, Length: 6635, dtype: object

# %%
percentage_counts = df['Completed'].value_counts(normalize=True) * 100

# Create a bar plot using Seaborn
custom_palette = ["#2a9d8f", "#f4a261", "#264653"]
plt.figure(figsize=(8, 6))
sns.set_palette(custom_palette)

# Use the 'barplot' function to create the bar graph
sns.barplot(x=percentage_counts.index, y=percentage_counts.values)

# Add labels and title
plt.xlabel('Completion Status')
plt.ylabel('Percentage of Learners')
plt.title('Percentage of Learners by Completion Status')

# Display percentages on top of each bar
for index, value in enumerate(percentage_counts.values):
    plt.text(index, value + 0.5, f'{value:.1f}%', ha='center', va='bottom')

plt.show()

# %%
percentage_counts

# %%
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#             Completed      Enrollment Time      Completion Time  \
# 0     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 1     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 2     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 3     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 4     Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# ...               ...                  ...                  ...
# 6630              Yes    15-02-23 11:48:06    17-03-23 06:11:14
# 6631               No    02-04-23 14:10:21  1900-01-01 00:00:00
# 6632  Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
# 6633              Yes    12-02-23 12:04:42    02-04-23 14:01:56
# 6634  Not Started Yet  1900-01-01 00:00:00  1900-01-01 00:00:00
#
#       Learning Hours Spent  Course Grade  \
# 0                     0.00          0.00
# 1                     0.00          0.00
# 2                     0.00          0.00
# 3                     0.00          0.00
# 4                     0.00          0.00
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                  0.00          0.00
# 6633                  6.34         90.00
# 6634                  0.00          0.00
#
#                                          Skills Learned
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...
# 1     Six Sigma; Training; Culture; Analysis; Leader...
# 2     Process Analysis; Process; Measurement; Genera...
# 3     Trigonometric Integral; Six Sigma; Leadership ...
# 4     Project; Conflict Management; Conflict Resolut...
# ...                                                 ...
# 6630  Data Visualization; Data Analysis; Analysis; P...
# 6631  Supply Chain; Finance; Chaining; Leadership an...
# 6632  Supply Chain; Trigonometric Integral; Lean Six...
# 6633  Data Visualization; Data Analysis; Analysis; P...
# 6634  General Statistics; Statistical Analysis; Prob...
#
# [6635 rows x 13 columns]

# %%
skills_counts = df_test['Skills Learned'].str.lower().str.split(';').explode().str.strip().value_counts()
df_skills_counts = pd.DataFrame({'Skill': skills_counts.index, 'Count': skills_counts.values})
df_skills_counts
# Out:
#                          Skill  Count
# 0                     analysis   3160
# 1    leadership and management   1607
# 2           data visualization   1488
# 3                data analysis   1412
# 4           general statistics   1325
# ..                         ...    ...
# 352           search algorithm      1
# 353                     graphs      1
# 354              apache hadoop      1
# 355             financial risk      1
# 356     personal advertisement      1
#
# [357 rows x 2 columns]

# %%
df_cleaned = df.dropna(subset=['Skills Learned'])

# Creating a dictionary to store the count of programs for each skill present in the dataset
skill_popularity = {}

# Iterate over rows and populate the dictionary
for index, row in df_cleaned.iterrows():
    skills = set(row['Skills Learned'].split('; '))

    for skill in skills:
        if skill not in skill_popularity:
            skill_popularity[skill] = 1
        else:
            skill_popularity[skill] += 1

# Converting the dictionary to a DataFrame
popularity_df = pd.DataFrame(list(skill_popularity.items()), columns=['Skill', 'Popularity'])

# Sort the DataFrame by popularity in descending order
popularity_df = popularity_df.sort_values(by='Popularity', ascending=False)

# Display the top skills
top_skills = popularity_df.head(11)

# Set a Seaborn color palette
sns.set_palette("pastel")

# Plot a bar graph using Seaborn
plt.figure(figsize=(11, 6))
sns.barplot(x='Skill', y='Popularity', data=top_skills, palette="pastel")
plt.xlabel('Skill')
plt.ylabel('Popularity')
plt.title('Top 10 Most Popular Skills Across Programs')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df['Enrollment Time'] = pd.to_datetime(df['Enrollment Time'], errors='coerce')
df['Completion Time'] = pd.to_datetime(df['Completion Time'], errors='coerce')

# Extract year and month from 'Enrollment Time' and 'Completion Time' columns
df['Enrollment YearMonth'] = df['Enrollment Time'].dt.to_period('M')
df['Completion YearMonth'] = df['Completion Time'].dt.to_period('M')

# Filter out records with '1900-01-01' in either 'Enrollment Time' or 'Completion Time'
df_filtered = df[(df['Enrollment YearMonth'].dt.to_timestamp() != '1900-01-01') & 
                 (df['Completion YearMonth'].dt.to_timestamp() != '1900-01-01')]

# Group by enrollment and completion time and count the number of records
enrollment_counts = df_filtered.groupby('Enrollment YearMonth').size()
completion_counts = df_filtered.groupby('Completion YearMonth').size()

# Create a DataFrame for plotting
plot_data = pd.DataFrame({'Enrollment': enrollment_counts, 'Completion': completion_counts})

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(plot_data.index.astype(str), plot_data['Enrollment'], marker='o', label='Enrollment')
plt.plot(plot_data.index.astype(str), plot_data['Completion'], marker='o', label='Completion')

# Annotate each marker with the number of learners
for x, y_enroll, y_complete in zip(plot_data.index.astype(str), plot_data['Enrollment'], plot_data['Completion']):
    plt.annotate(f'{y_enroll}', (x, y_enroll), textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(f'{y_complete}', (x, y_complete), textcoords="offset points", xytext=(0,-15), ha='center')

plt.xlabel('Year-Month')
plt.ylabel('Number of Learners')
plt.title('Enrollment and Completion Trends Over Time')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# - This basically shows the trebnds in the enrollemnt and the completion time of the it in the month of march

# %%
df['Enrollment Time']
# Out:
# 0      1900-01-01 00:00:00
# 1      1900-01-01 00:00:00
# 2      1900-01-01 00:00:00
# 3      1900-01-01 00:00:00
# 4      1900-01-01 00:00:00
#                ...
# 6630   2023-02-15 11:48:06
# 6631   2023-02-04 14:10:21
# 6632   1900-01-01 00:00:00
# 6633   2023-12-02 12:04:42
# 6634   1900-01-01 00:00:00
# Name: Enrollment Time, Length: 6635, dtype: datetime64[ns]

# %%
df['Completion Time']
# Out:
# 0      1900-01-01 00:00:00
# 1      1900-01-01 00:00:00
# 2      1900-01-01 00:00:00
# 3      1900-01-01 00:00:00
# 4      1900-01-01 00:00:00
#                ...
# 6630   2023-03-17 06:11:14
# 6631   1900-01-01 00:00:00
# 6632   1900-01-01 00:00:00
# 6633   2023-02-04 14:01:56
# 6634   1900-01-01 00:00:00
# Name: Completion Time, Length: 6635, dtype: datetime64[ns]

# %%
df['Enrollment Time'] = pd.to_datetime(df['Enrollment Time'], errors='coerce')
df['Completion Time'] = pd.to_datetime(df['Completion Time'], errors='coerce')

# Filter out records with both enrollment and completion times as '1900-01-01 00:00:00'
df_filtered = df[~((df['Enrollment Time'] == '1900-01-01 00:00:00') & (df['Completion Time'] == '1900-01-01 00:00:00'))]

# Group by enrollment and completion time and count the number of records
enrollment_counts = df_filtered.groupby('Enrollment YearMonth').size()
completion_counts = df_filtered.groupby('Completion YearMonth').size()

# Create a DataFrame for plotting
plot_data = pd.DataFrame({'Enrollment': enrollment_counts, 'Completion': completion_counts})

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(plot_data.index.astype(str), plot_data['Enrollment'], marker='o', label='Enrollment')
plt.plot(plot_data.index.astype(str), plot_data['Completion'], marker='o', label='Completion')

# Annotate each marker with the number of learners
for x, y_enroll, y_complete in zip(plot_data.index.astype(str), plot_data['Enrollment'], plot_data['Completion']):
    plt.annotate(f'{y_enroll}', (x, y_enroll), textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(f'{y_complete}', (x, y_complete), textcoords="offset points", xytext=(0,-15), ha='center')

plt.xlabel('Year-Month')
plt.ylabel('Number of Learners')
plt.title('Enrollment and Completion Trends Over Time (Excluding 1900-01)')
plt.legend()
plt.xticks(rotation=45, ha='right')

# Change the label on the x-axis tick corresponding to '1900-01'
labels = [item.get_text() if item.get_text() != '1900-01' else 'Not Completed Yet' for item in plt.gca().get_xticklabels()]
plt.gca().set_xticklabels(labels)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Siddharth\AppData\Local\Temp\ipykernel_5616\1735051928.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(labels)

# %%
df_not_completed_status = df[(df['Completed'] == 'No') & (df['Course Grade'] != 0)].copy()  
correlation_not_completed = df_not_completed_status['Learning Hours Spent'].corr(df_not_completed_status['Course Grade'])
print(f"Correlation for Not Completed Courses: {correlation_not_completed}")
# Out:
# Correlation for Not Completed Courses: 0.3816889520760214

# %%
df_completed_status = df[(df['Completed'] == 'Yes') & (df['Course Grade'] != 0)].copy()  
correlation_completed = df_completed_status['Learning Hours Spent'].corr(df_completed_status['Course Grade'])
print(f"Correlation for Completed Courses: {correlation_completed}")
# Out:
# Correlation for Completed Courses: 0.006028130526509626

# %%
df_all_courses = df[(df['Completed']!='Not Started Yet') & (df['Course Grade'] != 0)].copy()
correlation_all_courses = df_all_courses['Learning Hours Spent'].corr(df_all_courses['Course Grade'])
print(f"Correlation for All Courses: {correlation_all_courses}")
# Out:
# Correlation for All Courses: 0.27332228984922036

# %%
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#             Completed     Enrollment Time     Completion Time  \
# 0     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 1     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 2     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 3     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 4     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# ...               ...                 ...                 ...
# 6630              Yes 2023-02-15 11:48:06 2023-03-17 06:11:14
# 6631               No 2023-02-04 14:10:21 1900-01-01 00:00:00
# 6632  Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 6633              Yes 2023-12-02 12:04:42 2023-02-04 14:01:56
# 6634  Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
#
#       Learning Hours Spent  Course Grade  \
# 0                     0.00          0.00
# 1                     0.00          0.00
# 2                     0.00          0.00
# 3                     0.00          0.00
# 4                     0.00          0.00
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                  0.00          0.00
# 6633                  6.34         90.00
# 6634                  0.00          0.00
#
#                                          Skills Learned Enrollment YearMonth  \
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...              1900-01
# 1     Six Sigma; Training; Culture; Analysis; Leader...              1900-01
# 2     Process Analysis; Process; Measurement; Genera...              1900-01
# 3     Trigonometric Integral; Six Sigma; Leadership ...              1900-01
# 4     Project; Conflict Management; Conflict Resolut...              1900-01
# ...                                                 ...                  ...
# 6630  Data Visualization; Data Analysis; Analysis; P...              2023-02
# 6631  Supply Chain; Finance; Chaining; Leadership an...              2023-02
# 6632  Supply Chain; Trigonometric Integral; Lean Six...              1900-01
# 6633  Data Visualization; Data Analysis; Analysis; P...              2023-12
# 6634  General Statistics; Statistical Analysis; Prob...              1900-01
#
#      Completion YearMonth
# 0                 1900-01
# 1                 1900-01
# 2                 1900-01
# 3                 1900-01
# 4                 1900-01
# ...                   ...
# 6630              2023-03
# 6631              1900-01
# 6632              1900-01
# 6633              2023-02
# 6634              1900-01
#
# [6635 rows x 15 columns]

# %% [markdown]
# - Correlation for Not Completed Courses: 0.3817
#
# - Interpretation: There is a moderate positive correlation between learning hours and course grades for learners who have not completed their courses. As learning hours increase, there is a tendency for grades to improve.
#
# - Correlation for Completed Courses: 0.0060
#
# - Interpretation: There is a very weak positive correlation between learning hours and course grades for learners who have completed their courses. The relationship between learning hours and grades for completed courses is nearly negligible.
#
# - Correlation for All Courses: 0.2733
#
# - Interpretation: When considering all courses, including both completed and not completed, there is a moderate positive correlation between learning hours and course grades. The overall relationship suggests that, on average, more learning hours are associated with higher grades.
#
# - Comparison:
#
# - The highest correlation is observed for not completed courses, indicating a relatively stronger relationship between learning hours and grades for learners still in progress.
# - The correlation for completed courses is very low, suggesting that the time spent learning may not be a significant predictor of grades for those who have already completed the course.

# %%
plt.figure(figsize=(8, 6))

# Scatter plot for learning hours and course grade
sns.scatterplot(x='Learning Hours Spent', y='Course Grade', hue='Completed', data=df, palette=['blue', 'orange', 'green'])
plt.title('Learning Hours vs Course Grade')
plt.xlabel('Learning Hours')
plt.ylabel('Course Grade')

plt.tight_layout()
plt.show()

# %%
#The criteria for being a top performer in the dataset
score_threshold = 85
courses_completed_threshold = 3

# Filtering the DataFrame on the basis of course grade here 
high_performers_df = df[(df['Course Grade'] > score_threshold) & (df['Completed'] == 'Yes')]

# Filtering the DataFrame on the basis of no of skills in that course here 
high_performers_df = high_performers_df.groupby('Name').filter(lambda x: len(x) >= courses_completed_threshold)
high_performers_df
# Out:
#              Name              Division                        Group  \
# 107     Person_25           TQM and E&P  Projects & Construction TSK
# 108     Person_25           TQM and E&P  Projects & Construction TSK
# 111     Person_25           TQM and E&P  Projects & Construction TSK
# 183     Person_42       Shared Services       Electrical Maintenance
# 184     Person_42       Shared Services       Electrical Maintenance
# ...           ...                   ...                          ...
# 6342  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6343  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6344  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6346  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6347  Person_1347   Steel Manufacturing  Manufacturing Flat Products
#
#                               Department  \
# 107             Cold Rolling Mills - POG
# 108             Cold Rolling Mills - POG
# 111             Cold Rolling Mills - POG
# 183   Iron Making Electrical Maintenance
# 184   Iron Making Electrical Maintenance
# ...                                  ...
# 6342                          CRC - West
# 6343                          CRC - West
# 6344                          CRC - West
# 6346                          CRC - West
# 6347                          CRC - West
#
#                                 Program Name  \
# 107                School of Analytics-Basic
# 108                School of Analytics-Basic
# 111    Project Mgmt Learning Program-Generic
# 183                School of Analytics-Basic
# 184             IT Security Learning Program
# ...                                      ...
# 6342  Strategic Procurement Learning Program
# 6343  Strategic Procurement Learning Program
# 6344  Strategic Procurement Learning Program
# 6346  Strategic Procurement Learning Program
# 6347               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 107   Basic Data Descriptors Statistical Distributio...               8.9
# 108            Data – What It Is What We Can Do With It               5.8
# 111                    Initiating and Planning Projects               4.8
# 183   Basic Data Descriptors Statistical Distributio...               8.9
# 184   IT Security: Defense against the digital dark ...              13.4
# ...                                                 ...               ...
# 6342                             Supply Market Analysis               2.7
# 6343                Procurement & Sourcing Introduction               1.7
# 6344                                 Strategic Sourcing               3.0
# 6346                                 Procurement Basics               3.9
# 6347           Data – What It Is What We Can Do With It               5.8
#
#      Completed     Enrollment Time     Completion Time  Learning Hours Spent  \
# 107        Yes 2023-07-02 10:31:36 2023-02-28 12:03:05                  7.37
# 108        Yes 2023-07-02 10:27:38 2023-02-28 06:39:02                  7.70
# 111        Yes 2023-07-02 10:34:42 2023-07-05 09:10:08                  3.68
# 183        Yes 2023-09-04 07:41:14 2023-12-04 03:30:03                  2.78
# 184        Yes 2023-03-17 06:21:05 2023-09-04 07:35:21                 13.29
# ...        ...                 ...                 ...                   ...
# 6342       Yes 2023-05-13 07:15:40 2023-05-14 14:22:09                  0.52
# 6343       Yes 2023-09-05 10:16:48 2023-09-05 13:11:15                  1.01
# 6344       Yes 2023-10-05 04:18:59 2023-10-05 13:45:01                  0.41
# 6346       Yes 2023-09-05 13:28:29 2023-10-05 09:47:24                  1.49
# 6347       Yes 2023-03-13 14:17:21 2023-03-13 16:03:40                  1.72
#
#       Course Grade                                     Skills Learned  \
# 107          94.95  General Statistics; Statistical Analysis; Prob...
# 108          95.00  Data Visualization; Data Analysis; Analysis; P...
# 111         100.00  Project; Planning; Project Management; Project...
# 183          89.32  General Statistics; Statistical Analysis; Prob...
# 184          96.70  Wireless; Network Security; System Security; C...
# ...            ...                                                ...
# 6342        100.00  Supply Chain; Risk; Market Analysis; Market (E...
# 6343        100.00  Supply Chain; Sources; Supplier Relationship M...
# 6344         87.50                 Sources; Leadership and Management
# 6346        100.00  Supply Chain; Procurement; Leadership and Mana...
# 6347         90.00  Data Visualization; Data Analysis; Analysis; P...
#
#      Enrollment YearMonth Completion YearMonth
# 107               2023-07              2023-02
# 108               2023-07              2023-02
# 111               2023-07              2023-07
# 183               2023-09              2023-12
# 184               2023-03              2023-09
# ...                   ...                  ...
# 6342              2023-05              2023-05
# 6343              2023-09              2023-09
# 6344              2023-10              2023-10
# 6346              2023-09              2023-10
# 6347              2023-03              2023-03
#
# [265 rows x 15 columns]

# %% [markdown]
# - So there are 256 people who are in this top performers list out of the the 6635 peoples records and "high_performers_df" will contain the following record

# %%
sns.set(style="whitegrid")

# Plot the most popular programs
plt.figure(figsize=(10, 6))
top_programs = high_performers_df['Program Name'].value_counts().nlargest(5)
sns.barplot(x=top_programs, y=top_programs.index, palette="viridis")
plt.title('Most Popular Programs Among High-Performing Learners')
plt.xlabel('Number of Learners')
plt.ylabel('Program Name')
plt.show()

# %%
plt.figure(figsize=(10, 8))
top_skills = high_performers_df['Skills Learned'].str.split('; ').explode().value_counts().nlargest(10)
plt.pie(top_skills, labels=top_skills.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Blues"))
plt.title('Most Popular Skills Among High-Performing Learners')
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_courses = high_performers_df['Course Name'].value_counts().nlargest(5)
sns.barplot(x=top_courses, y=top_courses.index, palette="viridis")
plt.title('Most Popular Courses Among High-Performing Learners')
plt.xlabel('Number of Learners')
plt.ylabel('Course Name')
plt.show()

# %%
average_learning_hours_high_performers = high_performers_df['Learning Hours Spent'].mean()
print(f'The average learning hours for high-performing learners is: {average_learning_hours_high_performers:.2f} hours')
# Out:
# The average learning hours for high-performing learners is: 5.31 hours

# %%
completed_learners_df = df[df['Completed'] == 'Yes']
average_learning_hours_completed = completed_learners_df['Learning Hours Spent'].mean()
print(f'The average learning hours for all learners who have completed the course is: {average_learning_hours_completed:.2f} hours')
# Out:
# The average learning hours for all learners who have completed the course is: 5.48 hours

# %%
df=df_test
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#             Completed     Enrollment Time     Completion Time  \
# 0     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 1     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 2     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 3     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 4     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# ...               ...                 ...                 ...
# 6630              Yes 2023-02-15 11:48:06 2023-03-17 06:11:14
# 6631               No 2023-02-04 14:10:21 1900-01-01 00:00:00
# 6632  Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 6633              Yes 2023-12-02 12:04:42 2023-02-04 14:01:56
# 6634  Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
#
#       Learning Hours Spent  Course Grade  \
# 0                     0.00          0.00
# 1                     0.00          0.00
# 2                     0.00          0.00
# 3                     0.00          0.00
# 4                     0.00          0.00
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                  0.00          0.00
# 6633                  6.34         90.00
# 6634                  0.00          0.00
#
#                                          Skills Learned Enrollment YearMonth  \
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...              1900-01
# 1     Six Sigma; Training; Culture; Analysis; Leader...              1900-01
# 2     Process Analysis; Process; Measurement; Genera...              1900-01
# 3     Trigonometric Integral; Six Sigma; Leadership ...              1900-01
# 4     Project; Conflict Management; Conflict Resolut...              1900-01
# ...                                                 ...                  ...
# 6630  Data Visualization; Data Analysis; Analysis; P...              2023-02
# 6631  Supply Chain; Finance; Chaining; Leadership an...              2023-02
# 6632  Supply Chain; Trigonometric Integral; Lean Six...              1900-01
# 6633  Data Visualization; Data Analysis; Analysis; P...              2023-12
# 6634  General Statistics; Statistical Analysis; Prob...              1900-01
#
#      Completion YearMonth
# 0                 1900-01
# 1                 1900-01
# 2                 1900-01
# 3                 1900-01
# 4                 1900-01
# ...                   ...
# 6630              2023-03
# 6631              1900-01
# 6632              1900-01
# 6633              2023-02
# 6634              1900-01
#
# [6635 rows x 15 columns]

# %%
data = {'Category': ['All Completed Learners', 'High-Performing Learners'],
        'Average Learning Hours': [average_learning_hours_completed, average_learning_hours_high_performers]}

df_2 = pd.DataFrame(data)

# Create a grouped bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Average Learning Hours', data=df_2, palette=['blue', 'lightblue'])
plt.ylabel('Average Learning Hours')
plt.title('Average Learning Hours Comparison')

# Adding annotations to the top of the bars
for i, value in enumerate(df_2['Average Learning Hours']):
    plt.text(i, value + 0.1, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
program_skills_dict = {}

for index, row in df.iterrows():
    program_name = row['Program Name']
    skills = row['Skills Learned'].split('; ')
    
    if program_name not in program_skills_dict:
        program_skills_dict[program_name] = {'total_courses': 0, 'skills': {}}
    
    program_skills_dict[program_name]['total_courses'] += 1
    
    for skill in skills:
        if skill in program_skills_dict[program_name]['skills']:
            program_skills_dict[program_name]['skills'][skill] += 1
        else:
            program_skills_dict[program_name]['skills'][skill] = 1

# Creating a list of dictionaries to store program name, the most popular skill, and the percentage
data = []

for program, program_data in program_skills_dict.items():
    most_popular_skill = max(program_data['skills'], key=program_data['skills'].get)
    percentage_courses_with_skill = (program_data['skills'][most_popular_skill] / program_data['total_courses']) * 100
    data.append({
        'Program Name': program,
        'Most Popular Skill': most_popular_skill,
        'Popularity Percentage ': percentage_courses_with_skill
    })

# Creating a dataframe from the list of dictionaries
program_most_popular_skill = pd.DataFrame(data)
program_most_popular_skill
# Out:
#                                  Program Name Most Popular Skill  \
# 0       Six Sigma Black Belt Learning Program          Six Sigma
# 1                   School of Analytics-Basic           Analysis
# 2      Supply Chain Planning Learning Program       Supply Chain
# 3              School of Visualization ONE IT   Tableau Software
# 4            Teamwork Skills Learning Program      Team Building
# ..                                        ...                ...
# 129    Google Data Analytics Learning Program   Tableau Software
# 130      Communication Roles Learning Program          Marketing
# 131   Solve Business Problems- AI & ML ONE IT   Machine Learning
# 132  Leading Positive Change Learning Program  Change Management
# 133        Business Strategy Learning Program  Business Strategy
#
#      Popularity Percentage
# 0                 62.500000
# 1                100.000000
# 2                100.000000
# 3                100.000000
# 4                100.000000
# ..                      ...
# 129              100.000000
# 130               66.666667
# 131              100.000000
# 132              100.000000
# 133              100.000000
#
# [134 rows x 3 columns]

# %%
df
# Out:
#              Name          Division                        Group  \
# 0        Person_1  Operations - TSK          Steel & Mills - TSK
# 1        Person_1  Operations - TSK          Steel & Mills - TSK
# 2        Person_1  Operations - TSK          Steel & Mills - TSK
# 3        Person_1  Operations - TSK          Steel & Mills - TSK
# 4        Person_1  Operations - TSK          Steel & Mills - TSK
# ...           ...               ...                          ...
# 6630  Person_1408       TQM and E&P  Projects & Construction TSK
# 6631  Person_1409       TQM and E&P  Projects & Construction TSK
# 6632  Person_1409       TQM and E&P  Projects & Construction TSK
# 6633  Person_1409       TQM and E&P  Projects & Construction TSK
# 6634  Person_1409       TQM and E&P  Projects & Construction TSK
#
#                         Department                            Program Name  \
# 0     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 1     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 2     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 3     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# 4     Steel Melting Shop & LCP TSK   Six Sigma Black Belt Learning Program
# ...                            ...                                     ...
# 6630      Cold Rolling Mills - POG               School of Analytics-Basic
# 6631      Cold Rolling Mills - POG  Operations Management Learning Program
# 6632      Cold Rolling Mills - POG  Operations Management Learning Program
# 6633      Cold Rolling Mills - POG               School of Analytics-Basic
# 6634      Cold Rolling Mills - POG               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 0               The Define Phase for the 6 σ Black Belt               5.8
# 1              The Analyze Phase for the 6 σ Black Belt               7.5
# 2              The Measure Phase for the 6 σ Black Belt              10.8
# 3                           DFSS for the 6 σ Black Belt               5.0
# 4                Team Management for the 6 σ Black Belt               2.5
# ...                                                 ...               ...
# 6630           Data – What It Is What We Can Do With It               5.8
# 6631                            Supply Chain Excellence               6.8
# 6632                            Supply Chain Operations               7.6
# 6633           Data – What It Is What We Can Do With It               5.8
# 6634  Basic Data Descriptors Statistical Distributio...               8.9
#
#             Completed     Enrollment Time     Completion Time  \
# 0     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 1     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 2     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 3     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 4     Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# ...               ...                 ...                 ...
# 6630              Yes 2023-02-15 11:48:06 2023-03-17 06:11:14
# 6631               No 2023-02-04 14:10:21 1900-01-01 00:00:00
# 6632  Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
# 6633              Yes 2023-12-02 12:04:42 2023-02-04 14:01:56
# 6634  Not Started Yet 1900-01-01 00:00:00 1900-01-01 00:00:00
#
#       Learning Hours Spent  Course Grade  \
# 0                     0.00          0.00
# 1                     0.00          0.00
# 2                     0.00          0.00
# 3                     0.00          0.00
# 4                     0.00          0.00
# ...                    ...           ...
# 6630                  7.31         90.00
# 6631                  2.09         33.23
# 6632                  0.00          0.00
# 6633                  6.34         90.00
# 6634                  0.00          0.00
#
#                                          Skills Learned Enrollment YearMonth  \
# 0     Trigonometric Integral; Lean Six Sigma; Six Si...              1900-01
# 1     Six Sigma; Training; Culture; Analysis; Leader...              1900-01
# 2     Process Analysis; Process; Measurement; Genera...              1900-01
# 3     Trigonometric Integral; Six Sigma; Leadership ...              1900-01
# 4     Project; Conflict Management; Conflict Resolut...              1900-01
# ...                                                 ...                  ...
# 6630  Data Visualization; Data Analysis; Analysis; P...              2023-02
# 6631  Supply Chain; Finance; Chaining; Leadership an...              2023-02
# 6632  Supply Chain; Trigonometric Integral; Lean Six...              1900-01
# 6633  Data Visualization; Data Analysis; Analysis; P...              2023-12
# 6634  General Statistics; Statistical Analysis; Prob...              1900-01
#
#      Completion YearMonth
# 0                 1900-01
# 1                 1900-01
# 2                 1900-01
# 3                 1900-01
# 4                 1900-01
# ...                   ...
# 6630              2023-03
# 6631              1900-01
# 6632              1900-01
# 6633              2023-02
# 6634              1900-01
#
# [6635 rows x 15 columns]

# %%
df.head(12)
# Out:
#         Name          Division                          Group  \
# 0   Person_1  Operations - TSK            Steel & Mills - TSK
# 1   Person_1  Operations - TSK            Steel & Mills - TSK
# 2   Person_1  Operations - TSK            Steel & Mills - TSK
# 3   Person_1  Operations - TSK            Steel & Mills - TSK
# 4   Person_1  Operations - TSK            Steel & Mills - TSK
# 5   Person_1  Operations - TSK            Steel & Mills - TSK
# 6   Person_1  Operations - TSK            Steel & Mills - TSK
# 7   Person_1  Operations - TSK            Steel & Mills - TSK
# 8   Person_1  Operations - TSK            Steel & Mills - TSK
# 9   Person_1  Operations - TSK            Steel & Mills - TSK
# 10  Person_2         VP One SC  Integrated Planning & Service
# 11  Person_2         VP One SC  Integrated Planning & Service
#
#                                   Department  \
# 0               Steel Melting Shop & LCP TSK
# 1               Steel Melting Shop & LCP TSK
# 2               Steel Melting Shop & LCP TSK
# 3               Steel Melting Shop & LCP TSK
# 4               Steel Melting Shop & LCP TSK
# 5               Steel Melting Shop & LCP TSK
# 6               Steel Melting Shop & LCP TSK
# 7               Steel Melting Shop & LCP TSK
# 8               Steel Melting Shop & LCP TSK
# 9               Steel Melting Shop & LCP TSK
# 10  Master Production Planning & Margin Mgmt
# 11  Master Production Planning & Margin Mgmt
#
#                               Program Name  \
# 0    Six Sigma Black Belt Learning Program
# 1    Six Sigma Black Belt Learning Program
# 2    Six Sigma Black Belt Learning Program
# 3    Six Sigma Black Belt Learning Program
# 4    Six Sigma Black Belt Learning Program
# 5    Six Sigma Black Belt Learning Program
# 6    Six Sigma Black Belt Learning Program
# 7                School of Analytics-Basic
# 8                School of Analytics-Basic
# 9    Six Sigma Black Belt Learning Program
# 10               School of Analytics-Basic
# 11  Supply Chain Planning Learning Program
#
#                                           Course Name  Duration(in hrs)  \
# 0             The Define Phase for the 6 σ Black Belt               5.8
# 1            The Analyze Phase for the 6 σ Black Belt               7.5
# 2            The Measure Phase for the 6 σ Black Belt              10.8
# 3                         DFSS for the 6 σ Black Belt               5.0
# 4              Team Management for the 6 σ Black Belt               2.5
# 5   Organization Planning and Development for the ...               6.2
# 6            The Control Phase for the 6 σ Black Belt               6.0
# 7            Data – What It Is What We Can Do With It               5.8
# 8   Basic Data Descriptors Statistical Distributio...               8.9
# 9            The Improve Phase for the 6 σ Black Belt               5.0
# 10           Data – What It Is What We Can Do With It               5.8
# 11                              Supply Chain Planning               8.4
#
#           Completed     Enrollment Time Completion Time  Learning Hours Spent  \
# 0   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 1   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 2   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 3   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 4   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 5   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 6   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 7                No 2023-03-24 05:29:17      1900-01-01                  0.01
# 8   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 9   Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 10  Not Started Yet 1900-01-01 00:00:00      1900-01-01                  0.00
# 11               No 2023-04-24 07:02:35      1900-01-01                  0.09
#
#     Course Grade                                     Skills Learned  \
# 0            0.0  Trigonometric Integral; Lean Six Sigma; Six Si...
# 1            0.0  Six Sigma; Training; Culture; Analysis; Leader...
# 2            0.0  Process Analysis; Process; Measurement; Genera...
# 3            0.0  Trigonometric Integral; Six Sigma; Leadership ...
# 4            0.0  Project; Conflict Management; Conflict Resolut...
# 5            0.0  Planning; Trigonometric Integral; Leadership; ...
# 6            0.0                  Trigonometric Integral; Six Sigma
# 7            0.0  Data Visualization; Data Analysis; Analysis; P...
# 8            0.0  General Statistics; Statistical Analysis; Prob...
# 9            0.0                                           Planning
# 10           0.0  Data Visualization; Data Analysis; Analysis; P...
# 11           0.0  Supply Chain; Demand; Forecasting; Chaining; P...
#
#    Enrollment YearMonth Completion YearMonth
# 0               1900-01              1900-01
# 1               1900-01              1900-01
# 2               1900-01              1900-01
# 3               1900-01              1900-01
# 4               1900-01              1900-01
# 5               1900-01              1900-01
# 6               1900-01              1900-01
# 7               2023-03              1900-01
# 8               1900-01              1900-01
# 9               1900-01              1900-01
# 10              1900-01              1900-01
# 11              2023-04              1900-01

# %%
df['Completion Status'] = df['Completed'].apply(lambda x: 1 if x == 'Yes' else 0)

# Group by person and aggregate information
person_data = df.groupby('Name').agg({
    'Course Name': 'count',            # Number of courses enrolled
    'Completion Status': 'sum'         # Number of courses completed
}).reset_index()

# Calculate completion percentage
person_data['Completion Percentage'] = (person_data['Completion Status'] / person_data['Course Name']) * 100

# Rename columns for clarity
person_data.columns = ['Person', 'Enrolled Courses', 'Completed Courses', 'Completion Percentage']

person_data
# Out:
#            Person  Enrolled Courses  Completed Courses  Completion Percentage
# 0        Person_1                10                  0               0.000000
# 1       Person_10                 6                  0               0.000000
# 2      Person_100                 6                  0               0.000000
# 3     Person_1000                 6                  0               0.000000
# 4     Person_1001                 5                  0               0.000000
# ...           ...               ...                ...                    ...
# 1404   Person_995                 6                  1              16.666667
# 1405   Person_996                 3                  3             100.000000
# 1406   Person_997                 4                  0               0.000000
# 1407   Person_998                 4                  0               0.000000
# 1408   Person_999                 3                  0               0.000000
#
# [1409 rows x 4 columns]

# %%
completed_persons_new_dataframe = person_data[person_data['Completed Courses'] > 0]
completed_persons_new_dataframe
# Out:
#            Person  Enrolled Courses  Completed Courses  Completion Percentage
# 5     Person_1002                 5                  2              40.000000
# 10    Person_1007                 3                  1              33.333333
# 22    Person_1018                 2                  2             100.000000
# 29    Person_1024                 4                  4             100.000000
# 32    Person_1027                10                  4              40.000000
# ...           ...               ...                ...                    ...
# 1388   Person_980                 7                  1              14.285714
# 1392   Person_984                 6                  1              16.666667
# 1395   Person_987                 4                  1              25.000000
# 1404   Person_995                 6                  1              16.666667
# 1405   Person_996                 3                  3             100.000000
#
# [294 rows x 4 columns]

# %%
high_performers_df
# Out:
#              Name              Division                        Group  \
# 107     Person_25           TQM and E&P  Projects & Construction TSK
# 108     Person_25           TQM and E&P  Projects & Construction TSK
# 111     Person_25           TQM and E&P  Projects & Construction TSK
# 183     Person_42       Shared Services       Electrical Maintenance
# 184     Person_42       Shared Services       Electrical Maintenance
# ...           ...                   ...                          ...
# 6342  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6343  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6344  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6346  Person_1347   Steel Manufacturing  Manufacturing Flat Products
# 6347  Person_1347   Steel Manufacturing  Manufacturing Flat Products
#
#                               Department  \
# 107             Cold Rolling Mills - POG
# 108             Cold Rolling Mills - POG
# 111             Cold Rolling Mills - POG
# 183   Iron Making Electrical Maintenance
# 184   Iron Making Electrical Maintenance
# ...                                  ...
# 6342                          CRC - West
# 6343                          CRC - West
# 6344                          CRC - West
# 6346                          CRC - West
# 6347                          CRC - West
#
#                                 Program Name  \
# 107                School of Analytics-Basic
# 108                School of Analytics-Basic
# 111    Project Mgmt Learning Program-Generic
# 183                School of Analytics-Basic
# 184             IT Security Learning Program
# ...                                      ...
# 6342  Strategic Procurement Learning Program
# 6343  Strategic Procurement Learning Program
# 6344  Strategic Procurement Learning Program
# 6346  Strategic Procurement Learning Program
# 6347               School of Analytics-Basic
#
#                                             Course Name  Duration(in hrs)  \
# 107   Basic Data Descriptors Statistical Distributio...               8.9
# 108            Data – What It Is What We Can Do With It               5.8
# 111                    Initiating and Planning Projects               4.8
# 183   Basic Data Descriptors Statistical Distributio...               8.9
# 184   IT Security: Defense against the digital dark ...              13.4
# ...                                                 ...               ...
# 6342                             Supply Market Analysis               2.7
# 6343                Procurement & Sourcing Introduction               1.7
# 6344                                 Strategic Sourcing               3.0
# 6346                                 Procurement Basics               3.9
# 6347           Data – What It Is What We Can Do With It               5.8
#
#      Completed     Enrollment Time     Completion Time  Learning Hours Spent  \
# 107        Yes 2023-07-02 10:31:36 2023-02-28 12:03:05                  7.37
# 108        Yes 2023-07-02 10:27:38 2023-02-28 06:39:02                  7.70
# 111        Yes 2023-07-02 10:34:42 2023-07-05 09:10:08                  3.68
# 183        Yes 2023-09-04 07:41:14 2023-12-04 03:30:03                  2.78
# 184        Yes 2023-03-17 06:21:05 2023-09-04 07:35:21                 13.29
# ...        ...                 ...                 ...                   ...
# 6342       Yes 2023-05-13 07:15:40 2023-05-14 14:22:09                  0.52
# 6343       Yes 2023-09-05 10:16:48 2023-09-05 13:11:15                  1.01
# 6344       Yes 2023-10-05 04:18:59 2023-10-05 13:45:01                  0.41
# 6346       Yes 2023-09-05 13:28:29 2023-10-05 09:47:24                  1.49
# 6347       Yes 2023-03-13 14:17:21 2023-03-13 16:03:40                  1.72
#
#       Course Grade                                     Skills Learned  \
# 107          94.95  General Statistics; Statistical Analysis; Prob...
# 108          95.00  Data Visualization; Data Analysis; Analysis; P...
# 111         100.00  Project; Planning; Project Management; Project...
# 183          89.32  General Statistics; Statistical Analysis; Prob...
# 184          96.70  Wireless; Network Security; System Security; C...
# ...            ...                                                ...
# 6342        100.00  Supply Chain; Risk; Market Analysis; Market (E...
# 6343        100.00  Supply Chain; Sources; Supplier Relationship M...
# 6344         87.50                 Sources; Leadership and Management
# 6346        100.00  Supply Chain; Procurement; Leadership and Mana...
# 6347         90.00  Data Visualization; Data Analysis; Analysis; P...
#
#      Enrollment YearMonth Completion YearMonth
# 107               2023-07              2023-02
# 108               2023-07              2023-02
# 111               2023-07              2023-07
# 183               2023-09              2023-12
# 184               2023-03              2023-09
# ...                   ...                  ...
# 6342              2023-05              2023-05
# 6343              2023-09              2023-09
# 6344              2023-10              2023-10
# 6346              2023-09              2023-10
# 6347              2023-03              2023-03
#
# [265 rows x 15 columns]

# %%
unique_persons_count = high_performers_df['Name'].nunique()
print("Number of unique persons:", unique_persons_count)
# Out:
# Number of unique persons: 67

# %%
person_courses_dict = {}

# Populate the dictionary
for _, row in high_performers_df.iterrows():
    person = row['Name']
    course = row['Course Name']
    
    if person in person_courses_dict:
        person_courses_dict[person].append(course)
    else:
        person_courses_dict[person] = [course]
person_courses_dict
# Out:
# {'Person_25': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It',
#   'Initiating and Planning Projects'],
#  'Person_42': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'IT Security: Defense against the digital dark arts',
#   'Data – What It Is What We Can Do With It'],
#  'Person_79': ['Design Thinking for Innovation',
#   'Cybersecurity Compliance Framework & System Administration',
#   'Introduction to Cybersecurity Tools & Cyber Attacks'],
#  'Person_80': ['Design Thinking for Innovation',
#   'Intel® Network Academy - Network Transformation 101',
#   'Intel® Network Academy - Network Transformation 102'],
#  'Person_89': ['Python for Data Science AI & Development',
#   'Data Analysis with Python',
#   'Applied Data Science Capstone',
#   'Design Thinking for Innovation'],
#  'Person_94': ['Machine Learning with Python',
#   'Introduction to Deep Learning & Neural Networks with Keras',
#   'Design Thinking for Innovation'],
#  'Person_107': ['Design Thinking for Innovation',
#   'Engineering Project Management: Scope, Time and Cost Management',
#   'Engineering Project Management: Risk, Quality, Teams, and Procurement',
#   'Engineering Project Management: Initiating and Planning'],
#  'Person_183': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It',
#   'Team Management for the 6 σ Black Belt',
#   'Organization Planning and Development for the 6 σ Black Belt'],
#  'Person_192': ['Machine Learning with Python',
#   'Design Thinking for Innovation',
#   'Introduction to Deep Learning & Neural Networks with Keras'],
#  'Person_193': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It',
#   'IT Security: Defense against the digital dark arts'],
#  'Person_205': ['Design Thinking for Innovation',
#   'Machine Learning with Python',
#   'Introduction to Deep Learning & Neural Networks with Keras'],
#  'Person_217': ['Introduction to Deep Learning & Neural Networks with Keras',
#   'Deep Neural Networks with PyTorch',
#   'AI Capstone Project with Deep Learning'],
#  'Person_218': ['Data – What It Is What We Can Do With It',
#   'Team Management for the 6 σ Black Belt',
#   'Organization Planning and Development for the 6 σ Black Belt'],
#  'Person_242': ['Content Advertising & Social IMC',
#   'The Nuts and Bolts of Public Relations',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Marketing Channel Benefits'],
#  'Person_247': ['Construction Project Management',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_249': ['Entrepreneurial Mindset',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It'],
#  'Person_256': ['Inferential and Predictive Statistics for Business',
#   'Exploring and Producing Data for Business Decision Making',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_284': ['Exploring and Producing Data for Business Decision Making',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Inferential and Predictive Statistics for Business'],
#  'Person_302': ['Initiating and Planning Projects',
#   'Budgeting and Scheduling Projects',
#   'Managing Project Risks and Changes'],
#  'Person_335': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Excel Skills for Business: Intermediate II',
#   'Data – What It Is What We Can Do With It',
#   'Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Advanced',
#   'Excel Skills for Business: Essentials'],
#  'Person_351': ['Business Transformation with Google Cloud',
#   'Infrastructure and Application Modernization with Google Cloud',
#   'Design Thinking for Innovation'],
#  'Person_376': ['Introduction to Scrum Master Training',
#   'Combining Scrum with Other Agile Methodologies',
#   'Scrum Master Certification: Scrum Methodologies'],
#  'Person_398': ['Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Advanced',
#   'Data – What It Is What We Can Do With It',
#   'Excel Skills for Business: Essentials',
#   'Excel Skills for Business: Intermediate II'],
#  'Person_417': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It',
#   'IT Security: Defense against the digital dark arts'],
#  'Person_429': ['Design Thinking for Innovation',
#   'Machine Learning with Python',
#   'Introduction to Deep Learning & Neural Networks with Keras'],
#  'Person_535': ['Data – What It Is What We Can Do With It',
#   'Graphic Design',
#   'Successful Presentation',
#   'Effective Communication Capstone Project',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_582': ['Budgeting and Scheduling Projects',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It',
#   'Initiating and Planning Projects',
#   'Managing Project Risks and Changes'],
#  'Person_585': ['Managing Project Risks and Changes',
#   'Initiating and Planning Projects',
#   'Budgeting and Scheduling Projects'],
#  'Person_596': ['Initiating and Planning Projects',
#   'Budgeting and Scheduling Projects',
#   'Managing Project Risks and Changes',
#   'Project Management Project',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_614': ['The Improve Phase for the 6 σ Black Belt',
#   'The Analyze Phase for the 6 σ Black Belt',
#   'DFSS for the 6 σ Black Belt',
#   'Team Management for the 6 σ Black Belt',
#   'The Define Phase for the 6 σ Black Belt',
#   'Organization Planning and Development for the 6 σ Black Belt',
#   'The Control Phase for the 6 σ Black Belt'],
#  'Person_643': ['Python for Data Science AI & Development',
#   'Data Visualization with Python',
#   'Applied Data Science Capstone',
#   'Design Thinking for Innovation'],
#  'Person_646': ['Transacting on the Blockchain',
#   'Introduction to Blockchain Technologies',
#   'Budgeting and Scheduling Projects',
#   'Initiating and Planning Projects'],
#  'Person_648': ['Excel Skills for Business: Essentials',
#   'Excel Skills for Business: Advanced',
#   'Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Intermediate II',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_675': ['Six Sigma Advanced Define and Measure Phases',
#   'Six Sigma Advanced Analyze Phase',
#   'Six Sigma and the Organization (Advanced)'],
#  'Person_697': ['Business intelligence and data analytics: Generate insights',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It'],
#  'Person_727': ['Communication Strategies for a Virtual Age',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It'],
#  'Person_730': ['Team Management for the 6 σ Black Belt',
#   'The Control Phase for the 6 σ Black Belt',
#   'The Measure Phase for the 6 σ Black Belt',
#   'The Define Phase for the 6 σ Black Belt',
#   'Organization Planning and Development for the 6 σ Black Belt',
#   'Data – What It Is What We Can Do With It'],
#  'Person_739': ['Budgeting and Scheduling Projects',
#   'Managing Project Risks and Changes',
#   'Project Management Project',
#   'Initiating and Planning Projects',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_748': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Major Engineering Project Performance',
#   'Data – What It Is What We Can Do With It'],
#  'Person_769': ['Budgeting and Scheduling Projects',
#   'Initiating and Planning Projects',
#   'Data – What It Is What We Can Do With It',
#   'Managing Project Risks and Changes'],
#  'Person_782': ['Linear Algebra for Machine Learning and Data Science',
#   'Crash Course on Python',
#   'Calculus for Machine Learning and Data Science'],
#  'Person_783': ['Strategic management: Be competitive',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It'],
#  'Person_809': ['Excel Skills for Business: Essentials',
#   'Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Advanced',
#   'Excel Skills for Business: Intermediate II',
#   'Data – What It Is What We Can Do With It'],
#  'Person_859': ['Business Writing',
#   'Graphic Design',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_863': ['Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Construction Project Management'],
#  'Person_878': ['Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Essentials',
#   'Excel Skills for Business: Intermediate II',
#   'Excel Skills for Business: Advanced',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_921': ['FinTech Foundations and Overview',
#   'Essential Design Principles for Tableau',
#   'Fundamentals of Visualization with Tableau',
#   'Design Thinking for Innovation',
#   'Visual Analytics with Tableau'],
#  'Person_926': ['IT Security: Defense against the digital dark arts',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It'],
#  'Person_927': ['Scrum Master Certification: Scrum Methodologies',
#   'Data – What It Is What We Can Do With It',
#   'Introduction to Scrum Master Training',
#   'Scrum Master Certification: Scaling Agile and the Team-of-Teams',
#   'Combining Scrum with Other Agile Methodologies'],
#  'Person_949': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It',
#   'Construction Project Management'],
#  'Person_965': ['Major Engineering Project Performance',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Financing and Initiating Major Engineering Projects',
#   'Data – What It Is What We Can Do With It'],
#  'Person_973': ['Project Management Project',
#   'Managing Project Risks and Changes',
#   'Budgeting and Scheduling Projects'],
#  'Person_1027': ['Team Management for the 6 σ Black Belt',
#   'Organization Planning and Development for the 6 σ Black Belt',
#   'Data – What It Is What We Can Do With It'],
#  'Person_1029': ['Data – What It Is What We Can Do With It',
#   'Inferential and Predictive Statistics for Business',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Exploring and Producing Data for Business Decision Making'],
#  'Person_1064': ['Managing Project Risks and Changes',
#   'Initiating and Planning Projects',
#   'Budgeting and Scheduling Projects'],
#  'Person_1097': ['Effective Communication Capstone Project',
#   'Business Writing',
#   'Graphic Design',
#   'Successful Presentation',
#   'Data – What It Is What We Can Do With It',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_1107': ['Data – What It Is What We Can Do With It',
#   'Strategic management: Be competitive',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_1110': ['Budgeting and Scheduling Projects',
#   'Initiating and Planning Projects',
#   'Managing Project Risks and Changes'],
#  'Person_1123': ['Managing Project Risks and Changes',
#   'Budgeting and Scheduling Projects',
#   'Initiating and Planning Projects'],
#  'Person_1244': ['Excel Skills for Business: Essentials',
#   'Data – What It Is What We Can Do With It',
#   'Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Advanced',
#   'Excel Skills for Business: Intermediate II'],
#  'Person_1263': ['Initiating and Planning Projects',
#   'Data – What It Is What We Can Do With It',
#   'Budgeting and Scheduling Projects',
#   'Managing Project Risks and Changes',
#   'Project Management Project'],
#  'Person_1268': ['Introduction to Scrum Master Training',
#   'Scrum Master Certification: Scrum Methodologies',
#   'Combining Scrum with Other Agile Methodologies',
#   'Scrum Master Certification: Scaling Agile and the Team-of-Teams',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions'],
#  'Person_1271': ['Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Excel Skills for Business: Intermediate I',
#   'Excel Skills for Business: Essentials',
#   'Data – What It Is What We Can Do With It'],
#  'Person_1299': ['Introduction to Blockchain Technologies',
#   'Artificial Intelligence in Marketing',
#   'Business English: Planning & Negotiating',
#   'Design Thinking for Innovation'],
#  'Person_1310': ['Excel Skills for Business: Essentials',
#   'Excel Skills for Business: Intermediate II',
#   'Excel Skills for Business: Advanced',
#   'Excel Skills for Business: Intermediate I',
#   'Basic Data Descriptors Statistical Distributions and Application to Business Decisions',
#   'Data – What It Is What We Can Do With It'],
#  'Person_1346': ['Machine Learning with Python',
#   'Deep Neural Networks with PyTorch',
#   'Introduction to Deep Learning & Neural Networks with Keras',
#   'Design Thinking for Innovation'],
#  'Person_1347': ['Strategic Procurement and Sourcing Conclusions',
#   'Procurement Negotiation',
#   'Supplier Management',
#   'Supply Market Analysis',
#   'Procurement & Sourcing Introduction',
#   'Strategic Sourcing',
#   'Procurement Basics',
#   'Data – What It Is What We Can Do With It']}

# %%
division_unique_persons = high_performers_df.groupby('Division')['Name'].nunique().reset_index()

# Rename the column for clarity
division_unique_persons.columns = ['Division', 'Number of Unique Persons']

# Calculate the percentage of high performers in each division
division_unique_persons['Percentage of High Performers'] = (division_unique_persons['Number of Unique Persons'] / 67) * 100
division_unique_persons
# Out:
#                                    Division  Number of Unique Persons  \
# 0                       Steel Manufacturing                         2
# 1                                       HRM                         6
# 2                               Iron Making                         1
# 3                                    One IT                        13
# 4                          Operations - TSK                         2
# 5                             Raw Materials                         3
# 6                                       SHS                         3
# 7                           Shared Services                         7
# 8                               TQM and E&P                        17
# 9                                       TSM                         6
# 10                                 Tech&NMB                         3
# 11                                 VP - GSP                         1
# 12  VP Corp. Finance, Treasury & Risk Mgmt.                         1
# 13                                VP One SC                         2
#
#     Percentage of High Performers
# 0                        2.985075
# 1                        8.955224
# 2                        1.492537
# 3                       19.402985
# 4                        2.985075
# 5                        4.477612
# 6                        4.477612
# 7                       10.447761
# 8                       25.373134
# 9                        8.955224
# 10                       4.477612
# 11                       1.492537
# 12                       1.492537
# 13                       2.985075

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Percentage of High Performers', y='Division', data=division_unique_persons, palette='viridis')
plt.title('Percentage of High Performers by Division')
plt.xlabel('Percentage')
plt.ylabel('Division')
plt.show()

# %%
group_unique_persons = high_performers_df.groupby('Group')['Name'].nunique().reset_index()
group_unique_persons.columns = ['Group', 'Number of Unique Persons']
group_unique_persons['Percentage of High Performers'] = (group_unique_persons['Number of Unique Persons'] / 67) * 100
group_unique_persons
# Out:
#                                        Group  Number of Unique Persons  \
# 0                       Angul Operation - IM                         5
# 1                                Coke Plants                         1
# 2                  Coke, Sinter & Iron - TSK                         1
# 3                                 Commercial                         1
# 4                               Construction                         2
# 5                       Design & Engineering                         9
# 6                     Electrical Maintenance                         7
# 7                 Enterprise Risk Management                         1
# 8             HRM Center of Excellence (CoE)                         5
# 9   Industrial By-ProductsManagementDivision                         2
# 10                                 Logistics                         2
# 11       Logistics & Infrastructure Projects                         1
# 12               Manufacturing Flat Products                         2
# 13                             Not Available                        17
# 14                                   O M & Q                         3
# 15                               Procurement                         1
# 16                  Product Technology Group                         3
# 17               Projects & Construction TSK                         2
# 18                       Steel & Mills - TSK                         1
# 19                            Transformation                         1
#
#     Percentage of High Performers
# 0                        7.462687
# 1                        1.492537
# 2                        1.492537
# 3                        1.492537
# 4                        2.985075
# 5                       13.432836
# 6                       10.447761
# 7                        1.492537
# 8                        7.462687
# 9                        2.985075
# 10                       2.985075
# 11                       1.492537
# 12                       2.985075
# 13                      25.373134
# 14                       4.477612
# 15                       1.492537
# 16                       4.477612
# 17                       2.985075
# 18                       1.492537
# 19                       1.492537

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Percentage of High Performers', y='Group', data=group_unique_persons, palette='viridis')
plt.title('Percentage of High Performers by Group')
plt.xlabel('Percentage')
plt.ylabel('Group')
plt.show()

# %%
length = 67  # Total number of unique high performers
department_unique_persons = high_performers_df.groupby('Department')['Name'].nunique().reset_index()
department_unique_persons.columns = ['Department', 'Number of Unique Persons']
department_unique_persons['Percentage of High Performers'] = (department_unique_persons['Number of Unique Persons'] / length) * 100
department_unique_persons
# Out:
#                                   Department  Number of Unique Persons  \
# 0                                 Automation                         8
# 1                    Business Transformation                         1
# 2                                 CRC - West                         1
# 3                             Coke Plant TSK                         1
# 4                   Cold Rolling Mills - POG                         1
# 5                    Construction Electrical                         2
# 6                              D&E Equipment                         2
# 7                             D&E Structural                         1
# 8                                        DRI                         5
# 9                        Delivery Management                         1
# 10                       E&P Slurry Pipeline                         1
# 11  Engg – Instrument., Control & Automation                         1
# 12      Engg. Plant Electrics & Power System                         2
# 13  Engineering – Coke, Environment & Energy                         2
# 14                Enterprise Risk Management                         1
# 15                          Hooghly Met Coke                         1
# 16                        Hot Strip Mill TSK                         1
# 17  IBMD M&S-Marketing& Business Development                         1
# 18                  IT Engineering & Project                         1
# 19                         IT Infrastructure                         2
# 20                               IT Services                         2
# 21                       Indigenous Sourcing                         1
# 22        Iron Making Electrical Maintenance                         7
# 23                       Khondbond Iron mine                         2
# 24                                LD3 & TSCR                         1
# 25                    Learning & Development                         1
# 26                  Logistics-Inbound & Rail                         1
# 27                      New Initiatives IBMD                         1
# 28              Occupational Health Services                         1
# 29                Process Engg. Flat Product                         1
# 30          Productivity Services Department                         5
# 31                                  Projects                         1
# 32                         Quality Assurance                         1
# 33                               RMHS & RMPP                         1
# 34              Raw Material Handling System                         1
# 35                                Technology                         2
# 36                  Total Quality Management                         2
#
#     Percentage of High Performers
# 0                       11.940299
# 1                        1.492537
# 2                        1.492537
# 3                        1.492537
# 4                        1.492537
# 5                        2.985075
# 6                        2.985075
# 7                        1.492537
# 8                        7.462687
# 9                        1.492537
# 10                       1.492537
# 11                       1.492537
# 12                       2.985075
# 13                       2.985075
# 14                       1.492537
# 15                       1.492537
# 16                       1.492537
# 17                       1.492537
# 18                       1.492537
# 19                       2.985075
# 20                       2.985075
# 21                       1.492537
# 22                      10.447761
# 23                       2.985075
# 24                       1.492537
# 25                       1.492537
# 26                       1.492537
# 27                       1.492537
# 28                       1.492537
# 29                       1.492537
# 30                       7.462687
# 31                       1.492537
# 32                       1.492537
# 33                       1.492537
# 34                       1.492537
# 35                       2.985075
# 36                       2.985075

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Percentage of High Performers', y='Department', data=department_unique_persons, palette='viridis')
plt.title('Percentage of High Performers by Department')
plt.xlabel('Percentage')
plt.ylabel('Department')
plt.show()

# %%
total_high_performers = 67 
program_unique_persons = high_performers_df.groupby('Program Name')['Name'].nunique().reset_index()
program_unique_persons.columns = ['Program Name', 'Number of Unique Persons']
program_unique_persons['Percentage of High Performers'] = (program_unique_persons['Number of Unique Persons'] / total_high_performers) * 100
program_unique_persons
# Out:
#                                 Program Name  Number of Unique Persons  \
# 0     AI Engineering Learning Program ONE IT                         6
# 1    Agile Management-Engineering & Projects                         2
# 2    Business Communication Learning Program                         3
# 3     Business Intelligence Learning Program                         1
# 4       Communication Roles Learning Program                         1
# 5    Communication Strategy Learning Program                         1
# 6   Data-Based Decision Making Learning Prog                         3
# 7           Design Thinking Learning Program                        13
# 8    Digital Transformation Using GCP ONE IT                         1
# 9     Engineering Project Mgmt Learning Prog                         1
# 10  Entrepreneurial Mindset Learning Program                         1
# 11       Excel for Business Learning Program                         8
# 12           Fintech Learning Program ONE IT                         1
# 13              IT Security Learning Program                         4
# 14                Marketing Learning Program                         1
# 15       Mathematics for ML Learning Program                         1
# 16  Project Management Learning Program -E&P                         3
# 17     Project Mgmt Learning Program-Generic                        13
# 18      Python Crash Course Learning Program                         1
# 19      School of Analytics Basic for ONE IT                         2
# 20                 School of Analytics-Basic                        42
# 21                      School of Blockchain                         2
# 22            School of Visualization ONE IT                         1
# 23             Scrum Master Learning Program                         3
# 24   Security Engineering  Learn Prog ONE IT                         1
# 25     Six Sigma Black Belt Learning Program                         5
# 26     Six Sigma Green Belt Learning Program                         1
# 27        Software Defined Networking ONE IT                         1
# 28  Strategic Business Mgmt Learning Program                         2
# 29    Strategic Procurement Learning Program                         1
#
#     Percentage of High Performers
# 0                        8.955224
# 1                        2.985075
# 2                        4.477612
# 3                        1.492537
# 4                        1.492537
# 5                        1.492537
# 6                        4.477612
# 7                       19.402985
# 8                        1.492537
# 9                        1.492537
# 10                       1.492537
# 11                      11.940299
# 12                       1.492537
# 13                       5.970149
# 14                       1.492537
# 15                       1.492537
# 16                       4.477612
# 17                      19.402985
# 18                       1.492537
# 19                       2.985075
# 20                      62.686567
# 21                       2.985075
# 22                       1.492537
# 23                       4.477612
# 24                       1.492537
# 25                       7.462687
# 26                       1.492537
# 27                       1.492537
# 28                       2.985075
# 29                       1.492537

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Percentage of High Performers', y='Program Name', data=program_unique_persons, palette='viridis')
plt.title('Percentage of High Performers by Program')
plt.xlabel('Percentage')
plt.ylabel('Program Name')
plt.show()

# %%
course_stats = high_performers_df.groupby('Course Name')['Name'].agg(['nunique', lambda x: len(x) / len(high_performers_df) * 100]).reset_index()
course_stats.columns = ['Course Name', 'Number of Unique Persons', 'Percentage of High Performers']
course_stats
# Out:
#                                           Course Name  \
# 0              AI Capstone Project with Deep Learning
# 1                       Applied Data Science Capstone
# 2                Artificial Intelligence in Marketing
# 3   Basic Data Descriptors Statistical Distributio...
# 4                   Budgeting and Scheduling Projects
# ..                                                ...
# 73           The Improve Phase for the 6 σ Black Belt
# 74           The Measure Phase for the 6 σ Black Belt
# 75             The Nuts and Bolts of Public Relations
# 76                      Transacting on the Blockchain
# 77                      Visual Analytics with Tableau
#
#     Number of Unique Persons  Percentage of High Performers
# 0                          1                       0.377358
# 1                          2                       0.754717
# 2                          1                       0.377358
# 3                         32                      12.075472
# 4                         12                       4.528302
# ..                       ...                            ...
# 73                         1                       0.377358
# 74                         1                       0.377358
# 75                         1                       0.377358
# 76                         1                       0.377358
# 77                         1                       0.377358
#
# [78 rows x 3 columns]
